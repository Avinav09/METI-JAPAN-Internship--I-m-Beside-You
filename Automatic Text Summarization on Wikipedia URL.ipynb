# %%
#importing Beautiful Soup and URLLIB library for web scraping
import bs4 as bs
import urllib.request
import re

# %%
scraped_data = urllib.request.urlopen("https://en.wikipedia.org/wiki/Chi-squared_test")
article = scraped_data.read()

# %%
len(article)
# Out:
# 158404

# %%
parsed_article = bs.BeautifulSoup(article,'lxml')
parsed_article
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Chi-squared test - Wikipedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"2ba43e63-dc0d-4bfe-9378-0ef5f2fd9e15","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Chi-squared_test","wgTitle":"Chi-squared test","wgCurRevisionId":983024096,"wgRevisionId":983024096,"wgArticleId":226680,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["All articles with incomplete citations","Articles with incomplete citations from January 2013","Statistical tests for contingency tables","Nonparametric statistics"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Chi-squared_test","wgRelevantArticleId":
# 226680,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgWikibaseItemId":"Q1071004"};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","ext.math.styles":"ready","skins.vector.styles.legacy":"ready","jquery.makeCollapsible.styles":
# "ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","ext.math.scripts","ext.scribunto.logs","site","mediawiki.page.ready","jquery.makeCollapsible","mediawiki.toc","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});</script>
# <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.math.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
# <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>
# <meta content="" name="ResourceLoaderDynamicStyles"/>
# <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
# <meta content="MediaWiki 1.36.0-wmf.18" name="generator"/>
# <meta content="origin" name="referrer"/>
# <meta content="origin-when-crossorigin" name="referrer"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/8/8e/Chi-square_distributionCDF-English.png/1200px-Chi-square_distributionCDF-English.png" property="og:image"/>
# <link href="//upload.wikimedia.org" rel="preconnect"/>
# <link href="//en.m.wikipedia.org/wiki/Chi-squared_test" media="only screen and (max-width: 720px)" rel="alternate"/>
# <link href="/w/index.php?title=Chi-squared_test&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
# <link href="/w/index.php?title=Chi-squared_test&amp;action=edit" rel="edit" title="Edit this page"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
# <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
# <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
# <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
# <link href="https://en.wikipedia.org/wiki/Chi-squared_test" rel="canonical"/>
# <link href="//login.wikimedia.org" rel="dns-prefetch"/>
# <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Chi-squared_test rootpage-Chi-squared_test skin-vector action-view skin-vector-legacy"><div class="noprint" id="mw-page-base"></div>
# <div class="noprint" id="mw-head-base"></div>
# <div class="mw-body" id="content" role="main">
# <a id="top"></a>
# <div class="mw-body-content" id="siteNotice"><!-- CentralNotice --></div>
# <div class="mw-indicators mw-body-content">
# </div>
# <h1 class="firstHeading" id="firstHeading" lang="en">Chi-squared test</h1>
# <div class="mw-body-content" id="bodyContent">
# <div class="noprint" id="siteSub">From Wikipedia, the free encyclopedia</div>
# <div id="contentSub"></div>
# <div id="contentSub2"></div>
# <div id="jump-to-nav"></div>
# <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>
# <a class="mw-jump-link" href="#searchInput">Jump to search</a>
# <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><div class="mw-parser-output"><div class="thumb tright"><div class="thumbinner" style="width:302px;"><a class="image" href="/wiki/File:Chi-square_distributionCDF-English.png"><img alt="" class="thumbimage" data-file-height="1000" data-file-width="1311" decoding="async" height="229" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8e/Chi-square_distributionCDF-English.png/300px-Chi-square_distributionCDF-English.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8e/Chi-square_distributionCDF-English.png/450px-Chi-square_distributionCDF-English.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8e/Chi-square_distributionCDF-English.png/600px-Chi-square_distributionCDF-English.png 2x" width="300"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:Chi-square_distributionCDF-English.png" title="Enlarge"></a></div><a class="mw-redirect" href="/wiki/Chi-squared_distribution" title="Chi-squared distribution">Chi-squared distribution</a>, showing <span class="texhtml"><i>χ</i><sup>2</sup></span> on the <i>x</i>-axis and <i>p</i>-value (right tail probability) on the <i>y</i>-axis.</div></div></div>
# <p>A <b>chi-squared test</b>, also written as <b><span class="texhtml"><i>χ</i><sup>2</sup></span> test</b>, is a <a href="/wiki/Statistical_hypothesis_testing" title="Statistical hypothesis testing">statistical hypothesis test</a> that is <a href="/wiki/Validity_(statistics)" title="Validity (statistics)">valid</a> to perform when the test statistic is <a class="mw-redirect" href="/wiki/Chi-squared_distribution" title="Chi-squared distribution">chi-squared distributed</a> under the <a class="mw-redirect" href="/wiki/Null_hypothesis" title="Null hypothesis">null hypothesis</a>, specifically <a href="/wiki/Pearson%27s_chi-squared_test" title="Pearson's chi-squared test">Pearson's chi-squared test</a> and variants thereof. Pearson's chi-squared test is used to determine whether there is a <a href="/wiki/Statistical_significance" title="Statistical significance">statistically significant</a> difference between the expected <a href="/wiki/Frequency_(statistics)" title="Frequency (statistics)">frequencies</a> and the observed frequencies in one or more categories of a <a href="/wiki/Contingency_table" title="Contingency table">contingency table</a>.
# </p><p>In the standard applications of this test, the observations are classified into mutually exclusive classes. If the <a class="mw-redirect" href="/wiki/Null_hypothesis" title="Null hypothesis">null hypothesis</a> that there are no differences between the classes in the population is true, the test statistic computed from the observations follows a <span class="texhtml"><i>χ</i><sup>2</sup></span> <a href="/wiki/Frequency_distribution" title="Frequency distribution">frequency distribution</a>. The purpose of the test is to evaluate how likely the observed frequencies would be assuming the null hypothesis is true.
# </p><p>Test statistics that follow a <span class="texhtml"><i>χ</i><sup>2</sup></span> distribution occur when the observations are independent and <a href="/wiki/Normal_distribution" title="Normal distribution">normally distributed</a>, which assumptions are often justified under the <a href="/wiki/Central_limit_theorem" title="Central limit theorem">central limit theorem</a>. There are also <span class="texhtml"><i>χ</i><sup>2</sup></span> tests for testing the null hypothesis of independence of a pair of <a href="/wiki/Random_variable" title="Random variable">random variables</a> based on observations of the pairs.
# </p><p>Chi-squared tests often refers to tests for which the distribution of the test statistic approaches the <span class="texhtml"><i>χ</i><sup>2</sup></span> distribution <a href="/wiki/Asymptote" title="Asymptote">asymptotically</a>, meaning that the <a href="/wiki/Sampling_distribution" title="Sampling distribution">sampling distribution</a> (if the null hypothesis is true) of the test statistic approximates a chi-squared distribution more and more closely as <a href="/wiki/Sample_(statistics)" title="Sample (statistics)">sample</a> sizes increase.
# </p>
# <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#History"><span class="tocnumber">1</span> <span class="toctext">History</span></a>
# <ul>
# <li class="toclevel-2 tocsection-2"><a href="#Pearson's_chi-squared_test"><span class="tocnumber">1.1</span> <span class="toctext">Pearson's chi-squared test</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-3"><a href="#Other_examples_of_chi-squared_tests"><span class="tocnumber">2</span> <span class="toctext">Other examples of chi-squared tests</span></a>
# <ul>
# <li class="toclevel-2 tocsection-4"><a href="#Fisher's_exact_test"><span class="tocnumber">2.1</span> <span class="toctext">Fisher's exact test</span></a></li>
# <li class="toclevel-2 tocsection-5"><a href="#Binomial_test"><span class="tocnumber">2.2</span> <span class="toctext">Binomial test</span></a></li>
# <li class="toclevel-2 tocsection-6"><a href="#Other_chi-squared_tests"><span class="tocnumber">2.3</span> <span class="toctext">Other chi-squared tests</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-7"><a href="#Yates's_correction_for_continuity"><span class="tocnumber">3</span> <span class="toctext">Yates's correction for continuity</span></a></li>
# <li class="toclevel-1 tocsection-8"><a href="#Chi-squared_test_for_variance_in_a_normal_population"><span class="tocnumber">4</span> <span class="toctext">Chi-squared test for variance in a normal population</span></a></li>
# <li class="toclevel-1 tocsection-9"><a href="#Example_chi-squared_test_for_categorical_data"><span class="tocnumber">5</span> <span class="toctext">Example chi-squared test for categorical data</span></a></li>
# <li class="toclevel-1 tocsection-10"><a href="#Applications"><span class="tocnumber">6</span> <span class="toctext">Applications</span></a></li>
# <li class="toclevel-1 tocsection-11"><a href="#See_also"><span class="tocnumber">7</span> <span class="toctext">See also</span></a></li>
# <li class="toclevel-1 tocsection-12"><a href="#References"><span class="tocnumber">8</span> <span class="toctext">References</span></a></li>
# <li class="toclevel-1 tocsection-13"><a href="#Further_reading"><span class="tocnumber">9</span> <span class="toctext">Further reading</span></a></li>
# </ul>
# </div>
# <h2><span class="mw-headline" id="History">History</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Chi-squared_test&amp;action=edit&amp;section=1" title="Edit section: History">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>In the 19th century, statistical analytical methods were mainly applied in biological data analysis and it was customary for researchers to assume that observations followed a <a href="/wiki/Normal_distribution" title="Normal distribution">normal distribution</a>, such as <a class="mw-redirect" href="/wiki/Sir_George_Airy" title="Sir George Airy">Sir George Airy</a> and <a href="/wiki/Mansfield_Merriman" title="Mansfield Merriman">Professor Merriman</a>, whose works were criticized by <a href="/wiki/Karl_Pearson" title="Karl Pearson">Karl Pearson</a> in his 1900 paper.<sup class="reference" id="cite_ref-Pearson1900_1-0"><a href="#cite_note-Pearson1900-1">[1]</a></sup>
# </p><p>At the end of 19th century, Pearson noticed the existence of significant <a href="/wiki/Skewness" title="Skewness">skewness</a> within some biological observations. In order to model the observations regardless of being normal or skewed, Pearson, in a series of articles published from 1893 to 1916,<sup class="reference" id="cite_ref-Pearson1893_2-0"><a href="#cite_note-Pearson1893-2">[2]</a></sup><sup class="reference" id="cite_ref-Pearson1895_3-0"><a href="#cite_note-Pearson1895-3">[3]</a></sup><sup class="reference" id="cite_ref-Pearson1901_4-0"><a href="#cite_note-Pearson1901-4">[4]</a></sup><sup class="reference" id="cite_ref-Pearson1916_5-0"><a href="#cite_note-Pearson1916-5">[5]</a></sup> devised the <a href="/wiki/Pearson_distribution" title="Pearson distribution">Pearson distribution</a>, a family of continuous probability distributions, which includes the normal distribution and many skewed distributions, and proposed a method of statistical analysis consisting of using the Pearson distribution to model the observation and performing a test of goodness of fit to determine how well the model really fits to the observations.
# </p>
# <h3><span id="Pearson.27s_chi-squared_test"></span><span class="mw-headline" id="Pearson's_chi-squared_test">Pearson's chi-squared test</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Chi-squared_test&amp;action=edit&amp;section=2" title="Edit section: Pearson's chi-squared test">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <div class="hatnote navigation-not-searchable" role="note">See also: <a href="/wiki/Pearson%27s_chi-squared_test" title="Pearson's chi-squared test">Pearson's chi-squared test</a></div>
# <p>In 1900, Pearson published a paper<sup class="reference" id="cite_ref-Pearson1900_1-1"><a href="#cite_note-Pearson1900-1">[1]</a></sup> on the <span class="texhtml"><i>χ</i><sup>2</sup></span> test which is considered to be one of the foundations of modern statistics.<sup class="reference" id="cite_ref-Cochran1952_6-0"><a href="#cite_note-Cochran1952-6">[6]</a></sup> In this paper, Pearson investigated a test of goodness of fit.
# </p><p>Suppose that <span class="texhtml mvar" style="font-style:italic;">n</span> observations in a random sample from a population are classified into <span class="texhtml mvar" style="font-style:italic;">k</span> mutually exclusive classes with respective observed numbers <span class="texhtml mvar" style="font-style:italic;">x<sub>i</sub></span> (for <span class="texhtml"><i>i</i> = 1,2,…,<i>k</i></span>), and a null hypothesis gives the probability <span class="texhtml mvar" style="font-style:italic;">p<sub>i</sub></span> that an observation falls into the <span class="texhtml mvar" style="font-style:italic;">i</span>th class. So we have the expected numbers <span class="texhtml"><i>m<sub>i</sub></i> = <i>np<sub>i</sub></i></span> for all <span class="texhtml mvar" style="font-style:italic;">i</span>, where
# </p>
# <dl><dd><span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle {\begin{aligned}&amp;\sum _{i=1}^{k}{p_{i}}=1\\[8pt]&amp;\sum _{i=1}^{k}{m_{i}}=n\sum _{i=1}^{k}{p_{i}}=\sum _{i=1}^{k}x_{i}\end{aligned}}}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <mrow class="MJX-TeXAtom-ORD">
# <mtable columnalign="right left right left right left right left right left right left" columnspacing="0em 2em 0em 2em 0em 2em 0em 2em 0em 2em 0em" displaystyle="true" rowspacing="1.1em 0.3em">
# <mtr>
# <mtd></mtd>
# <mtd>
# <mi></mi>
# <munderover>
# <mo>∑<!-- ∑ --></mo>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# <mo>=</mo>
# <mn>1</mn>
# </mrow>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>k</mi>
# </mrow>
# </munderover>
# <mrow class="MJX-TeXAtom-ORD">
# <msub>
# <mi>p</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# </mrow>
# </msub>
# </mrow>
# <mo>=</mo>
# <mn>1</mn>
# </mtd>
# </mtr>
# <mtr>
# <mtd></mtd>
# <mtd>
# <mi></mi>
# <munderover>
# <mo>∑<!-- ∑ --></mo>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# <mo>=</mo>
# <mn>1</mn>
# </mrow>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>k</mi>
# </mrow>
# </munderover>
# <mrow class="MJX-TeXAtom-ORD">
# <msub>
# <mi>m</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# </mrow>
# </msub>
# </mrow>
# <mo>=</mo>
# <mi>n</mi>
# <munderover>
# <mo>∑<!-- ∑ --></mo>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# <mo>=</mo>
# <mn>1</mn>
# </mrow>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>k</mi>
# </mrow>
# </munderover>
# <mrow class="MJX-TeXAtom-ORD">
# <msub>
# <mi>p</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# </mrow>
# </msub>
# </mrow>
# <mo>=</mo>
# <munderover>
# <mo>∑<!-- ∑ --></mo>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# <mo>=</mo>
# <mn>1</mn>
# </mrow>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>k</mi>
# </mrow>
# </munderover>
# <msub>
# <mi>x</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# </mrow>
# </msub>
# </mtd>
# </mtr>
# </mtable>
# </mrow>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle {\begin{aligned}&amp;\sum _{i=1}^{k}{p_{i}}=1\\[8pt]&amp;\sum _{i=1}^{k}{m_{i}}=n\sum _{i=1}^{k}{p_{i}}=\sum _{i=1}^{k}x_{i}\end{aligned}}}</annotation>
# </semantics>
# </math></span><img alt="{\displaystyle {\begin{aligned}&amp;\sum _{i=1}^{k}{p_{i}}=1\\[8pt]&amp;\sum _{i=1}^{k}{m_{i}}=n\sum _{i=1}^{k}{p_{i}}=\sum _{i=1}^{k}x_{i}\end{aligned}}}" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/69331c954dbe94da0301bf56d14e4394ef545b08" style="vertical-align: -7.838ex; width:27.282ex; height:16.843ex;"/></span></dd></dl>
# <p>Pearson proposed that, under the circumstance of the null hypothesis being correct, as <span class="texhtml"><i>n</i> → ∞</span> the limiting distribution of the quantity given below is the <span class="texhtml"><i>χ</i><sup>2</sup></span> distribution.
# </p>
# <dl><dd><span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle X^{2}=\sum _{i=1}^{k}{\frac {(x_{i}-m_{i})^{2}}{m_{i}}}=\sum _{i=1}^{k}{{\frac {x_{i}^{2}}{m_{i}}}-n}}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <msup>
# <mi>X</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mn>2</mn>
# </mrow>
# </msup>
# <mo>=</mo>
# <munderover>
# <mo>∑<!-- ∑ --></mo>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# <mo>=</mo>
# <mn>1</mn>
# </mrow>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>k</mi>
# </mrow>
# </munderover>
# <mrow class="MJX-TeXAtom-ORD">
# <mfrac>
# <mrow>
# <mo stretchy="false">(</mo>
# <msub>
# <mi>x</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# </mrow>
# </msub>
# <mo>−<!-- − --></mo>
# <msub>
# <mi>m</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# </mrow>
# </msub>
# <msup>
# <mo stretchy="false">)</mo>
# <mrow class="MJX-TeXAtom-ORD">
# <mn>2</mn>
# </mrow>
# </msup>
# </mrow>
# <msub>
# <mi>m</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# </mrow>
# </msub>
# </mfrac>
# </mrow>
# <mo>=</mo>
# <munderover>
# <mo>∑<!-- ∑ --></mo>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# <mo>=</mo>
# <mn>1</mn>
# </mrow>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>k</mi>
# </mrow>
# </munderover>
# <mrow class="MJX-TeXAtom-ORD">
# <mrow class="MJX-TeXAtom-ORD">
# <mfrac>
# <msubsup>
# <mi>x</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# </mrow>
# <mrow class="MJX-TeXAtom-ORD">
# <mn>2</mn>
# </mrow>
# </msubsup>
# <msub>
# <mi>m</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# </mrow>
# </msub>
# </mfrac>
# </mrow>
# <mo>−<!-- − --></mo>
# <mi>n</mi>
# </mrow>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle X^{2}=\sum _{i=1}^{k}{\frac {(x_{i}-m_{i})^{2}}{m_{i}}}=\sum _{i=1}^{k}{{\frac {x_{i}^{2}}{m_{i}}}-n}}</annotation>
# </semantics>
# </math></span><img alt="{\displaystyle X^{2}=\sum _{i=1}^{k}{\frac {(x_{i}-m_{i})^{2}}{m_{i}}}=\sum _{i=1}^{k}{{\frac {x_{i}^{2}}{m_{i}}}-n}}" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/53b18fe1fe297a80676f41be3b107fe76b4e535b" style="vertical-align: -3.005ex; width:36.153ex; height:7.343ex;"/></span></dd></dl>
# <p>Pearson dealt first with the case in which the expected numbers <span class="texhtml mvar" style="font-style:italic;">m<sub>i</sub></span> are large enough known numbers in all cells assuming every <span class="texhtml mvar" style="font-style:italic;">x<sub>i</sub></span> may be taken as <a href="/wiki/Normal_distribution" title="Normal distribution">normally distributed</a>, and reached the result that, in the limit as <span class="texhtml mvar" style="font-style:italic;">n</span> becomes large, <span class="texhtml"><i>X</i><span style="padding-left:0.12em;"><sup>2</sup></span></span> follows the <span class="texhtml"><i>χ</i><sup>2</sup></span> distribution with <span class="texhtml"><i>k</i> − 1</span> degrees of freedom.
# </p><p>However, Pearson next considered the case in which the expected numbers depended on the parameters that had to be estimated from the sample, and suggested that, with the notation of <span class="texhtml mvar" style="font-style:italic;">m<sub>i</sub></span> being the true expected numbers and <span class="texhtml"><i>m</i>′<sub><i>i</i></sub></span> being the estimated expected numbers, the difference
# </p>
# <dl><dd><span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle X^{2}-{X'}^{2}=\sum _{i=1}^{k}{\frac {x_{i}^{2}}{m_{i}}}-\sum _{i=1}^{k}{\frac {x_{i}^{2}}{m'_{i}}}}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <msup>
# <mi>X</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mn>2</mn>
# </mrow>
# </msup>
# <mo>−<!-- − --></mo>
# <msup>
# <mrow class="MJX-TeXAtom-ORD">
# <msup>
# <mi>X</mi>
# <mo>′</mo>
# </msup>
# </mrow>
# <mrow class="MJX-TeXAtom-ORD">
# <mn>2</mn>
# </mrow>
# </msup>
# <mo>=</mo>
# <munderover>
# <mo>∑<!-- ∑ --></mo>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# <mo>=</mo>
# <mn>1</mn>
# </mrow>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>k</mi>
# </mrow>
# </munderover>
# <mrow class="MJX-TeXAtom-ORD">
# <mfrac>
# <msubsup>
# <mi>x</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# </mrow>
# <mrow class="MJX-TeXAtom-ORD">
# <mn>2</mn>
# </mrow>
# </msubsup>
# <msub>
# <mi>m</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# </mrow>
# </msub>
# </mfrac>
# </mrow>
# <mo>−<!-- − --></mo>
# <munderover>
# <mo>∑<!-- ∑ --></mo>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# <mo>=</mo>
# <mn>1</mn>
# </mrow>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>k</mi>
# </mrow>
# </munderover>
# <mrow class="MJX-TeXAtom-ORD">
# <mfrac>
# <msubsup>
# <mi>x</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# </mrow>
# <mrow class="MJX-TeXAtom-ORD">
# <mn>2</mn>
# </mrow>
# </msubsup>
# <msubsup>
# <mi>m</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mi>i</mi>
# </mrow>
# <mo>′</mo>
# </msubsup>
# </mfrac>
# </mrow>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle X^{2}-{X'}^{2}=\sum _{i=1}^{k}{\frac {x_{i}^{2}}{m_{i}}}-\sum _{i=1}^{k}{\frac {x_{i}^{2}}{m'_{i}}}}</annotation>
# </semantics>
# </math></span><img alt="{\displaystyle X^{2}-{X'}^{2}=\sum _{i=1}^{k}{\frac {x_{i}^{2}}{m_{i}}}-\sum _{i=1}^{k}{\frac {x_{i}^{2}}{m'_{i}}}}" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/57e027c8fa16ce5cde202f6d05f7bb0f129f99b8" style="vertical-align: -3.005ex; width:30.403ex; height:7.343ex;"/></span></dd></dl>
# <p>will usually be positive and small enough to be omitted. In a conclusion, Pearson argued that if we regarded <span class="texhtml"><i>X</i>′<span style="padding-left:0.12em;"><sup>2</sup></span></span> as also distributed as <span class="texhtml"><i>χ</i><sup>2</sup></span> distribution with <span class="texhtml"><i>k</i> − 1</span> degrees of freedom, the error in this approximation would not affect practical decisions. This conclusion caused some controversy in practical applications and was not settled for 20 years until Fisher's 1922 and 1924 papers.<sup class="reference" id="cite_ref-Fisher1922_7-0"><a href="#cite_note-Fisher1922-7">[7]</a></sup><sup class="reference" id="cite_ref-Fisher1924_8-0"><a href="#cite_note-Fisher1924-8">[8]</a></sup>
# </p>
# <h2><span class="mw-headline" id="Other_examples_of_chi-squared_tests">Other examples of chi-squared tests</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Chi-squared_test&amp;action=edit&amp;section=3" title="Edit section: Other examples of chi-squared tests">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>One <a href="/wiki/Test_statistic" title="Test statistic">test statistic</a> that follows a <a class="mw-redirect" href="/wiki/Chi-squared_distribution" title="Chi-squared distribution">chi-squared distribution</a> exactly is the test that the variance of a normally distributed population has a given value based on a <a class="mw-redirect" href="/wiki/Sample_variance" title="Sample variance">sample variance</a>. Such tests are uncommon in practice because the true variance of the population is usually unknown. However, there are several statistical tests where the <a class="mw-redirect" href="/wiki/Chi-squared_distribution" title="Chi-squared distribution">chi-squared distribution</a> is approximately valid:
# </p>
# <h3><span id="Fisher.27s_exact_test"></span><span class="mw-headline" id="Fisher's_exact_test">Fisher's exact test</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Chi-squared_test&amp;action=edit&amp;section=4" title="Edit section: Fisher's exact test">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>For an exact test used in place of the 2 x 2 chi-squared test for independence, see <a href="/wiki/Fisher%27s_exact_test" title="Fisher's exact test">Fisher's exact test</a>.
# </p>
# <h3><span class="mw-headline" id="Binomial_test">Binomial test</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Chi-squared_test&amp;action=edit&amp;section=5" title="Edit section: Binomial test">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>For an exact test used in place of the 2 x 1 chi-squared test for goodness of fit, see <a href="/wiki/Binomial_test" title="Binomial test">Binomial test</a>.
# </p>
# <h3><span class="mw-headline" id="Other_chi-squared_tests">Other chi-squared tests</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Chi-squared_test&amp;action=edit&amp;section=6" title="Edit section: Other chi-squared tests">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <ul><li><a href="/wiki/Cochran%E2%80%93Mantel%E2%80%93Haenszel_statistics" title="Cochran–Mantel–Haenszel statistics">Cochran–Mantel–Haenszel chi-squared test</a>.</li>
# <li><a href="/wiki/McNemar%27s_test" title="McNemar's test">McNemar's test</a>, used in certain <span class="nowrap">2 × 2</span> tables with pairing</li>
# <li><a href="/wiki/Tukey%27s_test_of_additivity" title="Tukey's test of additivity">Tukey's test of additivity</a></li>
# <li>The <a href="/wiki/Portmanteau_test" title="Portmanteau test">portmanteau test</a> in <a class="mw-redirect" href="/wiki/Time-series_analysis" title="Time-series analysis">time-series analysis</a>, testing for the presence of <a href="/wiki/Autocorrelation" title="Autocorrelation">autocorrelation</a></li>
# <li><a href="/wiki/Likelihood-ratio_test" title="Likelihood-ratio test">Likelihood-ratio tests</a> in general <a href="/wiki/Statistical_model" title="Statistical model">statistical modelling</a>, for testing whether there is evidence of the need to move from a simple model to a more complicated one (where the simple model is nested within the complicated one).</li></ul>
# <h2><span id="Yates.27s_correction_for_continuity"></span><span class="mw-headline" id="Yates's_correction_for_continuity">Yates's correction for continuity</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Chi-squared_test&amp;action=edit&amp;section=7" title="Edit section: Yates's correction for continuity">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div class="hatnote navigation-not-searchable" role="note">Main article: <a href="/wiki/Yates%27s_correction_for_continuity" title="Yates's correction for continuity">Yates's correction for continuity</a></div>
# <p>Using the <a class="mw-redirect" href="/wiki/Chi-squared_distribution" title="Chi-squared distribution">chi-squared distribution</a> to interpret <a href="/wiki/Pearson%27s_chi-squared_test" title="Pearson's chi-squared test">Pearson's chi-squared statistic</a> requires one to assume that the <a class="mw-redirect" href="/wiki/Discrete_probability_distribution" title="Discrete probability distribution">discrete</a> probability of observed <a href="/wiki/Binomial_distribution" title="Binomial distribution">binomial frequencies</a> in the table can be approximated by the continuous <a class="mw-redirect" href="/wiki/Chi-squared_distribution" title="Chi-squared distribution">chi-squared distribution</a>. This assumption is not quite correct and introduces some error.
# </p><p>To reduce the error in approximation, <a href="/wiki/Frank_Yates" title="Frank Yates">Frank Yates</a> suggested a correction for continuity that adjusts the formula for <a href="/wiki/Pearson%27s_chi-squared_test" title="Pearson's chi-squared test">Pearson's chi-squared test</a> by subtracting 0.5 from the absolute difference between each observed value and its expected value in a <span class="nowrap">2 × 2</span> contingency table.<sup class="reference" id="cite_ref-Yates_9-0"><a href="#cite_note-Yates-9">[9]</a></sup> This reduces the chi-squared value obtained and thus increases its <a href="/wiki/P-value" title="P-value"><i>p</i>-value</a>.
# </p>
# <h2><span class="mw-headline" id="Chi-squared_test_for_variance_in_a_normal_population">Chi-squared test for variance in a normal population</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Chi-squared_test&amp;action=edit&amp;section=8" title="Edit section: Chi-squared test for variance in a normal population">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>If a sample of size <span class="texhtml"><i>n</i></span> is taken from a population having a <a href="/wiki/Normal_distribution" title="Normal distribution">normal distribution</a>, then there is a result (see <a href="/wiki/Variance#Distribution_of_the_sample_variance" title="Variance">distribution of the sample variance</a>) which allows a test to be made of whether the variance of the population has a pre-determined value. For example, a manufacturing process might have been in stable condition for a long period, allowing a value for the variance to be determined essentially without error. Suppose that a variant of the process is being tested, giving rise to a small sample of <span class="texhtml"><i>n</i></span> product items whose variation is to be tested. The test statistic <span class="texhtml"><i>T</i></span> in this instance could be set to be the sum of squares about the sample mean, divided by the nominal value for the variance (i.e. the value to be tested as holding). Then <span class="texhtml"><i>T</i></span> has a chi-squared distribution with <span class="texhtml"><i>n</i> − 1</span> <a href="/wiki/Degrees_of_freedom_(statistics)" title="Degrees of freedom (statistics)">degrees of freedom</a>. For example, if the sample size is 21, the acceptance region for <span class="texhtml"><i>T</i></span> with a significance level of 5% is between 9.59 and 34.17.
# </p>
# <h2><span class="mw-headline" id="Example_chi-squared_test_for_categorical_data">Example chi-squared test for categorical data</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Chi-squared_test&amp;action=edit&amp;section=9" title="Edit section: Example chi-squared test for categorical data">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>Suppose there is a city of 1,000,000 residents with four neighborhoods: <span class="texhtml"><i>A</i></span>, <span class="texhtml"><i>B</i></span>, <span class="texhtml"><i>C</i></span>, and <span class="texhtml"><i>D</i></span>. A random sample of 650 residents of the city is taken and their occupation is recorded as <a class="mw-redirect" href="/wiki/Collar_workers" title="Collar workers">"white collar", "blue collar", or "no collar"</a>. The null hypothesis is that each person's neighborhood of residence is independent of the person's occupational classification.  The data are tabulated as:
# </p>
# <dl><dd><table class="wikitable" style="text-align: right;">
# <tbody><tr>
# <th></th>
# <th><span class="texhtml"><i>A</i></span></th>
# <th><span class="texhtml"><i>B</i></span></th>
# <th><span class="texhtml"><i>C</i></span></th>
# <th><span class="texhtml"><i>D</i></span></th>
# <th>total
# </th></tr>
# <tr>
# <td style="text-align: left;">White collar</td>
# <td>90</td>
# <td>60</td>
# <td>104</td>
# <td>95</td>
# <td>349
# </td></tr>
# <tr>
# <td style="text-align: left;">Blue collar</td>
# <td>30</td>
# <td>50</td>
# <td>51</td>
# <td>20</td>
# <td>151
# </td></tr>
# <tr>
# <td style="text-align: left;">No collar</td>
# <td>30</td>
# <td>40</td>
# <td>45</td>
# <td>35</td>
# <td>150
# </td></tr>
# <tr>
# <th style="text-align: left;">Total</th>
# <th>150</th>
# <th>150</th>
# <th>200</th>
# <th>150</th>
# <th>650
# </th></tr></tbody></table></dd></dl>
# <p>Let us take the sample living in neighborhood <span class="texhtml"><i>A</i></span>, 150, to estimate what proportion of the whole 1,000,000 live in neighborhood <span class="texhtml"><i>A</i></span>.  Similarly we take <span class="sfrac nowrap tion" role="math" style="display:inline-block; vertical-align:-0.5em; font-size:85%; text-align:center;"><span class="num" style="display:block; line-height:1em; margin:0 0.1em;">349</span><span class="slash visualhide">/</span><span class="den" style="display:block; line-height:1em; margin:0 0.1em; border-top:1px solid;">650</span></span> to estimate what proportion of the 1,000,000 are white-collar workers.  By the assumption of independence under the hypothesis we should "expect" the number of white-collar workers in neighborhood <span class="texhtml"><i>A</i></span> to be
# </p>
# <dl><dd><span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle 150\times {\frac {349}{650}}\approx 80.54}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <mn>150</mn>
# <mo>×<!-- × --></mo>
# <mrow class="MJX-TeXAtom-ORD">
# <mfrac>
# <mn>349</mn>
# <mn>650</mn>
# </mfrac>
# </mrow>
# <mo>≈<!-- ≈ --></mo>
# <mn>80.54</mn>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle 150\times {\frac {349}{650}}\approx 80.54}</annotation>
# </semantics>
# </math></span><img alt="{\displaystyle 150\times {\frac {349}{650}}\approx 80.54}" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/5e0a3964c4d11e71ac1cf1db2ecb2139ff96dbfb" style="vertical-align: -1.838ex; width:19.046ex; height:5.176ex;"/></span></dd></dl>
# <p>Then in that "cell" of the table, we have
# </p>
# <dl><dd><span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle {\frac {\left({\text{observed}}-{\text{expected}}\right)^{2}}{\text{expected}}}={\frac {\left(90-80.54\right)^{2}}{80.54}}\approx 1.11}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <mrow class="MJX-TeXAtom-ORD">
# <mfrac>
# <msup>
# <mrow>
# <mo>(</mo>
# <mrow>
# <mrow class="MJX-TeXAtom-ORD">
# <mtext>observed</mtext>
# </mrow>
# <mo>−<!-- − --></mo>
# <mrow class="MJX-TeXAtom-ORD">
# <mtext>expected</mtext>
# </mrow>
# </mrow>
# <mo>)</mo>
# </mrow>
# <mrow class="MJX-TeXAtom-ORD">
# <mn>2</mn>
# </mrow>
# </msup>
# <mtext>expected</mtext>
# </mfrac>
# </mrow>
# <mo>=</mo>
# <mrow class="MJX-TeXAtom-ORD">
# <mfrac>
# <msup>
# <mrow>
# <mo>(</mo>
# <mrow>
# <mn>90</mn>
# <mo>−<!-- − --></mo>
# <mn>80.54</mn>
# </mrow>
# <mo>)</mo>
# </mrow>
# <mrow class="MJX-TeXAtom-ORD">
# <mn>2</mn>
# </mrow>
# </msup>
# <mn>80.54</mn>
# </mfrac>
# </mrow>
# <mo>≈<!-- ≈ --></mo>
# <mn>1.11</mn>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle {\frac {\left({\text{observed}}-{\text{expected}}\right)^{2}}{\text{expected}}}={\frac {\left(90-80.54\right)^{2}}{80.54}}\approx 1.11}</annotation>
# </semantics>
# </math></span><img alt="{\displaystyle {\frac {\left({\text{observed}}-{\text{expected}}\right)^{2}}{\text{expected}}}={\frac {\left(90-80.54\right)^{2}}{80.54}}\approx 1.11}" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/e570bbdb142687764f315f95dd1348ab430cfdc7" style="vertical-align: -2.338ex; width:48.747ex; height:6.509ex;"/></span></dd></dl>
# <p>The sum of these quantities over all of the cells is the test statistic; in this case, <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle \approx 24.6}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <mo>≈<!-- ≈ --></mo>
# <mn>24.6</mn>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle \approx 24.6}</annotation>
# </semantics>
# </math></span><img alt="{\displaystyle \approx 24.6}" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/5563ccee54782d849cd48a119bf1c479a31ffa22" style="vertical-align: -0.338ex; width:6.588ex; height:2.176ex;"/></span>.  Under the null hypothesis, this sum has approximately a chi-squared distribution whose number of degrees of freedom are
# </p>
# <dl><dd><span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle ({\text{number of rows}}-1)({\text{number of columns}}-1)=(3-1)(4-1)=6}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <mo stretchy="false">(</mo>
# <mrow class="MJX-TeXAtom-ORD">
# <mtext>number of rows</mtext>
# </mrow>
# <mo>−<!-- − --></mo>
# <mn>1</mn>
# <mo stretchy="false">)</mo>
# <mo stretchy="false">(</mo>
# <mrow class="MJX-TeXAtom-ORD">
# <mtext>number of columns</mtext>
# </mrow>
# <mo>−<!-- − --></mo>
# <mn>1</mn>
# <mo stretchy="false">)</mo>
# <mo>=</mo>
# <mo stretchy="false">(</mo>
# <mn>3</mn>
# <mo>−<!-- − --></mo>
# <mn>1</mn>
# <mo stretchy="false">)</mo>
# <mo stretchy="false">(</mo>
# <mn>4</mn>
# <mo>−<!-- − --></mo>
# <mn>1</mn>
# <mo stretchy="false">)</mo>
# <mo>=</mo>
# <mn>6</mn>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle ({\text{number of rows}}-1)({\text{number of columns}}-1)=(3-1)(4-1)=6}</annotation>
# </semantics>
# </math></span><img alt="{\displaystyle ({\text{number of rows}}-1)({\text{number of columns}}-1)=(3-1)(4-1)=6}" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/bd2337dd322a2d5d67889cba1929a41a33d832ec" style="vertical-align: -0.838ex; width:67.466ex; height:2.843ex;"/></span></dd></dl>
# <p>If the test statistic is improbably large according to that chi-squared distribution, then one rejects the null hypothesis of independence.
# </p><p>A related issue is a test of homogeneity.  Suppose that instead of giving every resident of each of the four neighborhoods an equal chance of inclusion in the sample, we decide in advance how many residents of each neighborhood to include.  Then each resident has the same chance of being chosen as do all residents of the same neighborhood, but residents of different neighborhoods would have different probabilities of being chosen if the four sample sizes are not proportional to the populations of the four neighborhoods.  In such a case, we would be testing "homogeneity" rather than "independence".  The question is whether the proportions of blue-collar, white-collar, and no-collar workers in the four neighborhoods are the same.  However, the test is done in the same way.
# </p>
# <h2><span class="mw-headline" id="Applications">Applications</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Chi-squared_test&amp;action=edit&amp;section=10" title="Edit section: Applications">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>In <a href="/wiki/Cryptanalysis" title="Cryptanalysis">cryptanalysis</a>, the chi-squared test is used to compare the distribution of <a href="/wiki/Plaintext" title="Plaintext">plaintext</a> and (possibly) decrypted <a href="/wiki/Ciphertext" title="Ciphertext">ciphertext</a>. The lowest value of the test means that the decryption was successful with high probability.<sup class="reference" id="cite_ref-practicalcrypto_10-0"><a href="#cite_note-practicalcrypto-10">[10]</a></sup><sup class="reference" id="cite_ref-ibmath_11-0"><a href="#cite_note-ibmath-11">[11]</a></sup> This method can be generalized for solving modern cryptographic problems.<sup class="reference" id="cite_ref-elsevier_12-0"><a href="#cite_note-elsevier-12">[12]</a></sup>
# </p><p>In <a href="/wiki/Bioinformatics" title="Bioinformatics">bioinformatics</a>, chi-squared test is used to compare the distribution of certain properties of genes (e.g., genomic content, mutation rate, interaction network clustering, etc.) belonging to different categories (e.g., disease genes, essential genes, genes on a certain chromosome etc.).<sup class="reference" id="cite_ref-pnas-bics_13-0"><a href="#cite_note-pnas-bics-13">[13]</a></sup><sup class="reference" id="cite_ref-chi-bics_14-0"><a href="#cite_note-chi-bics-14">[14]</a></sup>
# </p>
# <h2><span class="mw-headline" id="See_also">See also</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Chi-squared_test&amp;action=edit&amp;section=11" title="Edit section: See also">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <style data-mw-deduplicate="TemplateStyles:r936637989">.mw-parser-output .portal{border:solid #aaa 1px;padding:0}.mw-parser-output .portal.tleft{margin:0.5em 1em 0.5em 0}.mw-parser-output .portal.tright{margin:0.5em 0 0.5em 1em}.mw-parser-output .portal>ul{display:table;box-sizing:border-box;padding:0.1em;max-width:175px;background:#f9f9f9;font-size:85%;line-height:110%;font-style:italic;font-weight:bold}.mw-parser-output .portal>ul>li{display:table-row}.mw-parser-output .portal>ul>li>span:first-child{display:table-cell;padding:0.2em;vertical-align:middle;text-align:center}.mw-parser-output .portal>ul>li>span:last-child{display:table-cell;padding:0.2em 0.2em 0.2em 0.3em;vertical-align:middle}</style><div aria-label="Portals" class="noprint portal plainlist tright" role="navigation">
# <ul>
# <li><span><a class="image" href="/wiki/File:Nuvola_apps_edu_mathematics_blue-p.svg"><img alt="icon" class="noviewer" data-file-height="128" data-file-width="128" decoding="async" height="28" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Nuvola_apps_edu_mathematics_blue-p.svg/28px-Nuvola_apps_edu_mathematics_blue-p.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Nuvola_apps_edu_mathematics_blue-p.svg/42px-Nuvola_apps_edu_mathematics_blue-p.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Nuvola_apps_edu_mathematics_blue-p.svg/56px-Nuvola_apps_edu_mathematics_blue-p.svg.png 2x" width="28"/></a></span><span><a href="/wiki/Portal:Mathematics" title="Portal:Mathematics">Mathematics portal</a></span></li></ul></div>
# <ul><li><a href="/wiki/Contingency_table" title="Contingency table">Contingency table</a></li>
# <li><a href="/wiki/Nomogram#Chi-squared_test_computation_nomogram" title="Nomogram">Chi-squared test nomogram</a></li>
# <li><a href="/wiki/G-test" title="G-test"><i>G</i>-test</a></li>
# <li><a href="/wiki/Minimum_chi-square_estimation" title="Minimum chi-square estimation">Minimum chi-square estimation</a></li>
# <li><a href="/wiki/Nonparametric_statistics" title="Nonparametric statistics">Nonparametric statistics</a></li>
# <li><a href="/wiki/Wald_test" title="Wald test">Wald test</a></li>
# <li><a class="mw-redirect" href="/wiki/Wilson_score_interval#Binomial_proportion_confidence_interval" title="Wilson score interval">Wilson score interval</a></li></ul>
# <h2><span class="mw-headline" id="References">References</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Chi-squared_test&amp;action=edit&amp;section=12" title="Edit section: References">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div class="reflist" style="list-style-type: decimal;">
# <div class="mw-references-wrap mw-references-columns"><ol class="references">
# <li id="cite_note-Pearson1900-1"><span class="mw-cite-backlink">^ <a href="#cite_ref-Pearson1900_1-0"><sup><i><b>a</b></i></sup></a> <a href="#cite_ref-Pearson1900_1-1"><sup><i><b>b</b></i></sup></a></span> <span class="reference-text">
# ...
# </div>
# </nav>
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-cactions-label" class="mw-portlet mw-portlet-cactions emptyPortlet vector-menu vector-menu-dropdown" id="p-cactions" role="navigation">
# <input aria-labelledby="p-cactions-label" class="vector-menu-checkbox" type="checkbox"/>
# <h3 id="p-cactions-label">
# <span>More</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"></ul>
# </div>
# </nav>
# <div id="p-search" role="search">
# <h3>
# <label for="searchInput">Search</label>
# </h3>
# <form action="/w/index.php" id="searchform">
# <div data-search-loc="header-navigation" id="simpleSearch">
# <input accesskey="f" autocapitalize="sentences" id="searchInput" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" type="search"/>
# <input name="title" type="hidden" value="Special:Search"/>
# <input class="searchButton mw-fallbackSearchButton" id="mw-searchButton" name="fulltext" title="Search Wikipedia for this text" type="submit" value="Search"/>
# <input class="searchButton" id="searchButton" name="go" title="Go to a page with this exact name if it exists" type="submit" value="Go"/>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div id="mw-panel">
# <div id="p-logo" role="banner">
# <a class="mw-wiki-logo" href="/wiki/Main_Page" title="Visit the main page"></a>
# </div>
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-navigation-label" class="mw-portlet mw-portlet-navigation vector-menu vector-menu-portal portal portal-first" id="p-navigation" role="navigation">
# <h3 id="p-navigation-label">
# <span>Navigation</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li id="n-mainpage-description"><a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]">Main page</a></li><li id="n-contents"><a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia">Contents</a></li><li id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Articles related to current events">Current events</a></li><li id="n-randompage"><a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]">Random article</a></li><li id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works">About Wikipedia</a></li><li id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">Contact us</a></li><li id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation">Donate</a></li></ul>
# </div>
# </nav>
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-interaction-label" class="mw-portlet mw-portlet-interaction vector-menu vector-menu-portal portal" id="p-interaction" role="navigation">
# <h3 id="p-interaction-label">
# <span>Contribute</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li><li id="n-introduction"><a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia">Learn to edit</a></li><li id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="The hub for editors">Community portal</a></li><li id="n-recentchanges"><a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]">Recent changes</a></li><li id="n-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Add images or other media for use on Wikipedia">Upload file</a></li></ul>
# </div>
# </nav>
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-tb-label" class="mw-portlet mw-portlet-tb vector-menu vector-menu-portal portal" id="p-tb" role="navigation">
# <h3 id="p-tb-label">
# <span>Tools</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li id="t-whatlinkshere"><a accesskey="j" href="/wiki/Special:WhatLinksHere/Chi-squared_test" title="List of all English Wikipedia pages containing links to this page [j]">What links here</a></li><li id="t-recentchangeslinked"><a accesskey="k" href="/wiki/Special:RecentChangesLinked/Chi-squared_test" rel="nofollow" title="Recent changes in pages linked from this page [k]">Related changes</a></li><li id="t-upload"><a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]">Upload file</a></li><li id="t-specialpages"><a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]">Special pages</a></li><li id="t-permalink"><a href="/w/index.php?title=Chi-squared_test&amp;oldid=983024096" title="Permanent link to this revision of this page">Permanent link</a></li><li id="t-info"><a href="/w/index.php?title=Chi-squared_test&amp;action=info" title="More information about this page">Page information</a></li><li id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Chi-squared_test&amp;id=983024096&amp;wpFormIdentifier=titleform" title="Information on how to cite this page">Cite this page</a></li><li id="t-wikibase"><a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q1071004" title="Structured data on this page hosted by Wikidata [g]">Wikidata item</a></li></ul>
# </div>
# </nav>
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-coll-print_export-label" class="mw-portlet mw-portlet-coll-print_export vector-menu vector-menu-portal portal" id="p-coll-print_export" role="navigation">
# <h3 id="p-coll-print_export-label">
# <span>Print/export</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li id="coll-download-as-rl"><a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=Chi-squared_test&amp;action=show-download-screen" title="Download this page as a PDF file">Download as PDF</a></li><li id="t-print"><a accesskey="p" href="/w/index.php?title=Chi-squared_test&amp;printable=yes" title="Printable version of this page [p]">Printable version</a></li></ul>
# </div>
# </nav>
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-lang-label" class="mw-portlet mw-portlet-lang vector-menu vector-menu-portal portal" id="p-lang" role="navigation">
# <h3 id="p-lang-label">
# <span>Languages</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="interlanguage-link interwiki-ar"><a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/%D8%A7%D8%AE%D8%AA%D8%A8%D8%A7%D8%B1_%D9%85%D8%B1%D8%A8%D8%B9_%D9%83%D8%A7%D9%8A" hreflang="ar" lang="ar" title="اختبار مربع كاي – Arabic">العربية</a></li><li class="interlanguage-link interwiki-cs"><a class="interlanguage-link-target" href="https://cs.wikipedia.org/wiki/Ch%C3%AD-kvadr%C3%A1t_test" hreflang="cs" lang="cs" title="Chí-kvadrát test – Czech">Čeština</a></li><li class="interlanguage-link interwiki-da"><a class="interlanguage-link-target" href="https://da.wikipedia.org/wiki/Chi_i_anden-test" hreflang="da" lang="da" title="Chi i anden-test – Danish">Dansk</a></li><li class="interlanguage-link interwiki-de"><a class="interlanguage-link-target" href="https://de.wikipedia.org/wiki/Chi-Quadrat-Test" hreflang="de" lang="de" title="Chi-Quadrat-Test – German">Deutsch</a></li><li class="interlanguage-link interwiki-el"><a class="interlanguage-link-target" href="https://el.wikipedia.org/wiki/%CE%94%CE%BF%CE%BA%CE%B9%CE%BC%CE%B1%CF%83%CE%AF%CE%B1_X2" hreflang="el" lang="el" title="Δοκιμασία X2 – Greek">Ελληνικά</a></li><li class="interlanguage-link interwiki-es"><a class="interlanguage-link-target" href="https://es.wikipedia.org/wiki/Prueba_%CF%87%C2%B2" hreflang="es" lang="es" title="Prueba χ² – Spanish">Español</a></li><li class="interlanguage-link interwiki-eu"><a class="interlanguage-link-target" href="https://eu.wikipedia.org/wiki/Khi-karratuaren_proba" hreflang="eu" lang="eu" title="Khi-karratuaren proba – Basque">Euskara</a></li><li class="interlanguage-link interwiki-fa"><a class="interlanguage-link-target" href="https://fa.wikipedia.org/wiki/%D8%A2%D8%B2%D9%85%D9%88%D9%86_%D9%85%D8%B1%D8%A8%D8%B9_%DA%A9%D8%A7%DB%8C" hreflang="fa" lang="fa" title="آزمون مربع کای – Persian">فارسی</a></li><li class="interlanguage-link interwiki-fr"><a class="interlanguage-link-target" href="https://fr.wikipedia.org/wiki/Test_du_%CF%87%C2%B2" hreflang="fr" lang="fr" title="Test du χ² – French">Français</a></li><li class="interlanguage-link interwiki-ga"><a class="interlanguage-link-target" href="https://ga.wikipedia.org/wiki/Triail_ch%C3%AD-chearn%C3%B3ige" hreflang="ga" lang="ga" title="Triail chí-chearnóige – Irish">Gaeilge</a></li><li class="interlanguage-link interwiki-gl"><a class="interlanguage-link-target" href="https://gl.wikipedia.org/wiki/Test_khi_cadrado" hreflang="gl" lang="gl" title="Test khi cadrado – Galician">Galego</a></li><li class="interlanguage-link interwiki-ko"><a class="interlanguage-link-target" href="https://ko.wikipedia.org/wiki/%EC%B9%B4%EC%9D%B4%EC%A0%9C%EA%B3%B1_%EA%B2%80%EC%A0%95" hreflang="ko" lang="ko" title="카이제곱 검정 – Korean">한국어</a></li><li class="interlanguage-link interwiki-hi"><a class="interlanguage-link-target" href="https://hi.wikipedia.org/wiki/%E0%A4%95%E0%A4%BE%E0%A4%88-%E0%A4%B5%E0%A4%B0%E0%A5%8D%E0%A4%97_%E0%A4%AA%E0%A4%B0%E0%A5%80%E0%A4%95%E0%A5%8D%E0%A4%B7%E0%A4%A3" hreflang="hi" lang="hi" title="काई-वर्ग परीक्षण – Hindi">हिन्दी</a></li><li class="interlanguage-link interwiki-it"><a class="interlanguage-link-target" href="https://it.wikipedia.org/wiki/Test_chi_quadrato" hreflang="it" lang="it" title="Test chi quadrato – Italian">Italiano</a></li><li class="interlanguage-link interwiki-he"><a class="interlanguage-link-target" href="https://he.wikipedia.org/wiki/%D7%9E%D7%91%D7%97%D7%9F_%D7%9B%D7%99_%D7%91%D7%A8%D7%99%D7%91%D7%95%D7%A2" hreflang="he" lang="he" title="מבחן כי בריבוע – Hebrew">עברית</a></li><li class="interlanguage-link interwiki-sw"><a class="interlanguage-link-target" href="https://sw.wikipedia.org/wiki/Jaribio_la_%CF%87%C2%B2" hreflang="sw" lang="sw" title="Jaribio la χ² – Swahili">Kiswahili</a></li><li class="interlanguage-link interwiki-lv"><a class="interlanguage-link-target" href="https://lv.wikipedia.org/wiki/H%C4%AB_kvadr%C4%81ta_krit%C4%93rijs" hreflang="lv" lang="lv" title="Hī kvadrāta kritērijs – Latvian">Latviešu</a ...
# <div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q1071004#sitelinks-wikipedia" title="Edit interlanguage links">Edit links</a></span></div>
# </div>
# </nav>
# </div>
# </div>
# <footer class="mw-footer" id="footer" role="contentinfo">
# <ul id="footer-info">
# <li id="footer-info-lastmod"> This page was last edited on 11 October 2020, at 19:58<span class="anonymous-show"> (UTC)</span>.</li>
# <li id="footer-info-copyright">Text is available under the <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">Creative Commons Attribution-ShareAlike License</a><a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//foundation.wikimedia.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# </ul>
# <ul id="footer-places">
# <li id="footer-places-privacy"><a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">Privacy policy</a></li>
# <li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# <li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# <li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# <li id="footer-places-mobileview"><a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=Chi-squared_test&amp;mobileaction=toggle_view_mobile">Mobile view</a></li>
# <li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# <li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/en.wikipedia.org">Statistics</a></li>
# <li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Cookie_statement">Cookie statement</a></li>
# </ul>
# <ul class="noprint" id="footer-icons">
# <li id="footer-copyrightico"><a href="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/></a></li>
# <li id="footer-poweredbyico"><a href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/></a></li>
# </ul>
# <div style="clear: both;"></div>
# </footer>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.544","walltime":"0.718","ppvisitednodes":{"value":2480,"limit":1000000},"postexpandincludesize":{"value":195594,"limit":2097152},"templateargumentsize":{"value":1780,"limit":2097152},"expansiondepth":{"value":13,"limit":40},"expensivefunctioncount":{"value":2,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":61933,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%  532.139      1 -total"," 37.67%  200.444      1 Template:Reflist"," 29.35%  156.190     11 Template:Cite_journal"," 22.85%  121.592      1 Template:Statistics"," 21.94%  116.774      1 Template:Navbox_with_collapsible_groups"," 14.44%   76.823     11 Template:Navbox","  7.92%   42.168      1 Template:Full_citation_needed","  7.45%   39.667      1 Template:Portal","  7.15%   38.045      1 Template:Fix","  4.87%   25.900      1 Template:Category_handler"]},"scribunto":{"limitreport-timeusage":{"value":"0.261","limit":"10.000"},"limitreport-memusage":{"value":5943027,"limit":52428800},"limitreport-logs":"table#1 {\n}\n"},"cachereport":{"origin":"mw1261","timestamp":"20201123193659","ttl":2592000,"transientcontent":false}}});});</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"Chi-squared test","url":"https:\/\/en.wikipedia.org\/wiki\/Chi-squared_test","sameAs":"http:\/\/www.wikidata.org\/entity\/Q1071004","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q1071004","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2003-05-14T00:09:46Z","dateModified":"2020-10-11T19:58:06Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/8\/8e\/Chi-square_distributionCDF-English.png","headline":"Statistical procedure evaluated by reference to the chi-square distribution"}</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":196,"wgHostname":"mw1354"});});</script>
# </body></html>

# %%
len(parsed_article)
# Out:
# 2

# %%
paragraphs = parsed_article.find_all('p')

# %%
article_text = ""

# %%
for p in paragraphs:
    article_text += p.text

# %%
# this is our final scraped text data 
article_text
# Out:
# 'A chi-squared test, also written as χ2 test, is a statistical hypothesis test that is valid to perform when the test statistic is chi-squared distributed under the null hypothesis, specifically Pearson\'s chi-squared test and variants thereof. Pearson\'s chi-squared test is used to determine whether there is a statistically significant difference between the expected frequencies and the observed frequencies in one or more categories of a contingency table. \nIn the standard applications of this test, the observations are classified into mutually exclusive classes. If the null hypothesis that there are no differences between the classes in the population is true, the test statistic computed from the observations follows a χ2 frequency distribution. The purpose of the test is to evaluate how likely the observed frequencies would be assuming the null hypothesis is true.\nTest statistics that follow a χ2 distribution occur when the observations are independent and normally distributed, which assumptions are often justified under the central limit theorem. There are also χ2 tests for testing the null hypothesis of independence of a pair of random variables based on observations of the pairs.\nChi-squared tests often refers to tests for which the distribution of the test statistic approaches the χ2 distribution asymptotically, meaning that the sampling distribution (if the null hypothesis is true) of the test statistic approximates a chi-squared distribution more and more closely as sample sizes increase.\nIn the 19th century, statistical analytical methods were mainly applied in biological data analysis and it was customary for researchers to assume that observations followed a normal distribution, such as Sir George Airy and Professor Merriman, whose works were criticized by Karl Pearson in his 1900 paper.[1]\nAt the end of 19th century, Pearson noticed the existence of significant skewness within some biological observations. In order to model the observations regardless of being normal or skewed, Pearson, in a series of articles published from 1893 to 1916,[2][3][4][5] devised the Pearson distribution, a family of continuous probability distributions, which includes the normal distribution and many skewed distributions, and proposed a method of statistical analysis consisting of using the Pearson distribution to model the observation and performing a test of goodness of fit to determine how well the model really fits to the observations.\nIn 1900, Pearson published a paper[1] on the χ2 test which is considered to be one of the foundations of modern statistics.[6] In this paper, Pearson investigated a test of goodness of fit.\nSuppose that n observations in a random sample from a population are classified into k mutually exclusive classes with respective observed numbers xi (for i = 1,2,…,k), and a null hypothesis gives the probability pi that an observation falls into the ith class. So we have the expected numbers mi = npi for all i, where\nPearson proposed that, under the circumstance of the null hypothesis being correct, as n → ∞ the limiting distribution of the quantity given below is the χ2 distribution.\nPearson dealt first with the case in which the expected numbers mi are large enough known numbers in all cells assuming every xi may be taken as normally distributed, and reached the result that, in the limit as n becomes large, X2 follows the χ2 distribution with k − 1 degrees of freedom.\nHowever, Pearson next considered the case in which the expected numbers depended on the parameters that had to be estimated from the sample, and suggested that, with the notation of mi being the true expected numbers and m′i being the estimated expected numbers, the difference\nwill usually be positive and small enough to be omitted. In a conclusion, Pearson argued that if we regarded X′2 as also distributed as χ2 distribution with k − 1 degrees of freedom, the error in this approximation would not affect practical decisions. This concl ...

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
stop_words = list(STOP_WORDS)
print(stop_words)
# Out:
# ['other', 'into', 'on', 'cannot', 'both', 'much', 'be', 'them', '‘m', 'rather', 'anywhere', 'too', 'hence', 'n‘t', 'noone', 'anything', 'someone', 'hundred', 'why', 'ca', 'would', 'can', 'already', 'thereby', 'sixty', 'whence', 'me', 'used', 'three', 'namely', 'yours', 'last', 'each', 'take', 'had', 'must', 'could', 'meanwhile', 'first', 'thence', "'ve", 'across', 'done', 'again', 'the', 'may', 'back', 'various', 'whose', 'these', 'out', 'any', 'whom', 'made', 'neither', 'others', 'two', 'most', 'those', 'towards', 'forty', 'never', 'about', 'doing', 'thereupon', 'therefore', 'up', 'name', 'hereafter', 'everywhere', 'should', 'a', 'among', 'do', '‘ll', 'front', 'amount', 'beyond', 'herein', 'former', 'yourselves', 'seemed', 'many', 'eleven', 'using', 'sometimes', 'thus', 'under', 'off', "'ll", 'eight', 'it', 'own', 'anyone', 'therein', 'did', 'from', 'call', 'perhaps', 'will', 'either', 'formerly', 'next', 'am', 'nine', 'whenever', '’ll', 'without', 'empty', 'who', 'five', 'are', 'is', 'throughout', 'whither', 'latterly', 'more', 'no', 'wherever', 'anyway', 'less', 'between', 'whether', 'yet', 'than', 'here', 'down', 'itself', 'fifty', 'themselves', 'hereby', 'been', 'mine', 'that', 'full', 're', 'go', 'except', 'per', 'in', 'give', 'were', 'nowhere', 'i', 'get', 'of', 'to', 'serious', 'becomes', 'twenty', 'besides', 'what', 'together', 'such', 'by', 'with', 'beforehand', 'nobody', '‘s', 'always', 'few', 'him', 'wherein', 'might', 'after', 'nevertheless', 'elsewhere', 'have', "'re", 'against', 'through', 'she', 'their', 'ours', 'us', 'bottom', 'being', 'below', 'anyhow', 'one', 'some', '’ve', 'behind', 'upon', 'this', '’s', 'himself', 'say', 'because', 'myself', 'well', "'m", 'whereafter', 'seems', 'alone', 'something', 'along', 'became', 'else', 'our', '‘d', '’re', 'latter', 'fifteen', 'does', 'for', 'you', 'ourselves', 'every', 'he', "'d", 'they', 'only', 'just', 'another', 'at', 'thru', 'please', 'his', 'while', 'least', '‘ve', "n't", 'beside', 'twelve', '’d', 'but', 'all', 'however', 'whole', 'become', 'afterwards', 'via', 'enough', 'nothing', 'part', 'over', 'make', 'top', 'onto', 'which', 'during', 'keep', 'there', 'still', 'as', 'ever', 'seeming', 'toward', 'once', 'until', 'moreover', 'was', 'everyone', 'also', 'even', 'has', 'now', 'somewhere', 'nor', 'not', 'quite', 'regarding', 'due', 'indeed', 'mostly', 'my', 'whereby', 'if', 'although', 'so', 'whoever', 'your', 'n’t', 'though', 'sometime', 'see', 'when', 'none', 'becoming', 'her', 'hereupon', 'yourself', 'then', 'seem', '‘re', 'unless', 'somehow', 'really', 'we', 'same', 'third', 'amongst', 'almost', 'where', 'otherwise', 'put', "'s", 'an', 'whatever', 'before', 'ten', 'show', 'herself', 'or', 'six', 'move', 'around', 'whereupon', 'within', 'its', 'whereas', 'since', 'thereafter', 'often', 'several', 'everything', 'how', 'and', 'above', 'four', '’m', 'further', 'very', 'side', 'hers']

# %%
#creation of spacy object
nlp = spacy.load('en_core_web_sm')

# %%
#loading the text data to use it for spacy
doc = nlp(article_text)

# %%
#tokenization of words
token = [token.text for token in doc]
print(token)
# Out:
# ['A', 'chi', '-', 'squared', 'test', ',', 'also', 'written', 'as', 'χ2', 'test', ',', 'is', 'a', 'statistical', 'hypothesis', 'test', 'that', 'is', 'valid', 'to', 'perform', 'when', 'the', 'test', 'statistic', 'is', 'chi', '-', 'squared', 'distributed', 'under', 'the', 'null', 'hypothesis', ',', 'specifically', 'Pearson', "'s", 'chi', '-', 'squared', 'test', 'and', 'variants', 'thereof', '.', 'Pearson', "'s", 'chi', '-', 'squared', 'test', 'is', 'used', 'to', 'determine', 'whether', 'there', 'is', 'a', 'statistically', 'significant', 'difference', 'between', 'the', 'expected', 'frequencies', 'and', 'the', 'observed', 'frequencies', 'in', 'one', 'or', 'more', 'categories', 'of', 'a', 'contingency', 'table', '.', '\n', 'In', 'the', 'standard', 'applications', 'of', 'this', 'test', ',', 'the', 'observations', 'are', 'classified', 'into', 'mutually', 'exclusive', 'classes', '.', 'If', 'the', 'null', 'hypothesis', 'that', 'there', 'are', 'no', 'differences', 'between', 'the', 'classes', 'in', 'the', 'population', 'is', 'true', ',', 'the', 'test', 'statistic', 'computed', 'from', 'the', 'observations', 'follows', 'a', 'χ2', 'frequency', 'distribution', '.', 'The', 'purpose', 'of', 'the', 'test', 'is', 'to', 'evaluate', 'how', 'likely', 'the', 'observed', 'frequencies', 'would', 'be', 'assuming', 'the', 'null', 'hypothesis', 'is', 'true', '.', '\n', 'Test', 'statistics', 'that', 'follow', 'a', 'χ2', 'distribution', 'occur', 'when', 'the', 'observations', 'are', 'independent', 'and', 'normally', 'distributed', ',', 'which', 'assumptions', 'are', 'often', 'justified', 'under', 'the', 'central', 'limit', 'theorem', '.', 'There', 'are', 'also', 'χ2', 'tests', 'for', 'testing', 'the', 'null', 'hypothesis', 'of', 'independence', 'of', 'a', 'pair', 'of', 'random', 'variables', 'based', 'on', 'observations', 'of', 'the', 'pairs', '.', '\n', 'Chi', '-', 'squared', 'tests', 'often', 'refers', 'to', 'tests', 'for', 'which', 'the', 'distribution', 'of', 'the', 'test', 'statistic', 'approaches', 'the', 'χ2', 'distribution', 'asymptotically', ',', 'meaning', 'that', 'the', 'sampling', 'distribution', '(', 'if', 'the', 'null', 'hypothesis', 'is', 'true', ')', 'of', 'the', 'test', 'statistic', 'approximates', 'a', 'chi', '-', 'squared', 'distribution', 'more', 'and', 'more', 'closely', 'as', 'sample', 'sizes', 'increase', '.', '\n', 'In', 'the', '19th', 'century', ',', 'statistical', 'analytical', 'methods', 'were', 'mainly', 'applied', 'in', 'biological', 'data', 'analysis', 'and', 'it', 'was', 'customary', 'for', 'researchers', 'to', 'assume', 'that', 'observations', 'followed', 'a', 'normal', 'distribution', ',', 'such', 'as', 'Sir', 'George', 'Airy', 'and', 'Professor', 'Merriman', ',', 'whose', 'works', 'were', 'criticized', 'by', 'Karl', 'Pearson', 'in', 'his', '1900', 'paper.[1', ']', '\n', 'At', 'the', 'end', 'of', '19th', 'century', ',', 'Pearson', 'noticed', 'the', 'existence', 'of', 'significant', 'skewness', 'within', 'some', 'biological', 'observations', '.', 'In', 'order', 'to', 'model', 'the', 'observations', 'regardless', 'of', 'being', 'normal', 'or', 'skewed', ',', 'Pearson', ',', 'in', 'a', 'series', 'of', 'articles', 'published', 'from', '1893', 'to', '1916,[2][3][4][5', ']', 'devised', 'the', 'Pearson', 'distribution', ',', 'a', 'family', 'of', 'continuous', 'probability', 'distributions', ',', 'which', 'includes', 'the', 'normal', 'distribution', 'and', 'many', 'skewed', 'distributions', ',', 'and', 'proposed', 'a', 'method', 'of', 'statistical', 'analysis', 'consisting', 'of', 'using', 'the', 'Pearson', 'distribution', 'to', 'model', 'the', 'observation', 'and', 'performing', 'a', 'test', 'of', 'goodness', 'of', 'fit', 'to', 'determine', 'how', 'well', 'the', 'model', 'really', 'fits', 'to', 'the', 'observations', '.', '\n', 'In', '1900', ',', 'Pearson', 'published', 'a', 'paper[1', ']', 'on', 'the', 'χ2', 'test', 'which', 'is', 'considered', 'to', 'be', 'one', 'of', 'the', 'foundations', 'of', 'modern', 'statistics.[6', ']',  ...

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#adding "\n" into punctuation list 
punctuation  = punctuation + '\n'
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\n'

# %%
#creation of word frequency table
word_frequencies = { }
for words in doc:
    if words.text.lower() not in stop_words:
        if words.text.lower() not in punctuation:
            if words.text.isnumeric() is False:
                if words.text not in word_frequencies.keys():
                    word_frequencies[words.text] = 1
                else:
                    word_frequencies[words.text] += 1

# %%
word_frequencies
# Out:
# {'chi': 19,
#  'squared': 20,
#  'test': 32,
#  'written': 1,
#  'χ2': 9,
#  'statistical': 4,
#  'hypothesis': 12,
#  'valid': 2,
#  'perform': 1,
#  'statistic': 9,
#  'distributed': 5,
#  'null': 10,
#  'specifically': 1,
#  'Pearson': 15,
#  'variants': 1,
#  'thereof': 1,
#  'determine': 2,
#  'statistically': 1,
#  'significant': 2,
#  'difference': 3,
#  'expected': 7,
#  'frequencies': 4,
#  'observed': 5,
#  'categories': 2,
#  'contingency': 2,
#  'table': 3,
#  'standard': 1,
#  'applications': 2,
#  'observations': 9,
#  'classified': 2,
#  'mutually': 2,
#  'exclusive': 2,
#  'classes': 3,
#  'differences': 1,
#  'population': 6,
#  'true': 5,
#  'computed': 1,
#  'follows': 3,
#  'frequency': 1,
#  'distribution': 25,
#  'purpose': 1,
#  'evaluate': 1,
#  'likely': 1,
#  'assuming': 2,
#  'Test': 1,
#  'statistics': 1,
#  'follow': 1,
#  'occur': 1,
#  'independent': 2,
#  'normally': 3,
#  'assumptions': 1,
#  'justified': 1,
#  'central': 1,
#  'limit': 2,
#  'theorem': 1,
#  'tests': 5,
#  'testing': 2,
#  'independence': 5,
#  'pair': 1,
#  'random': 3,
#  'variables': 1,
#  'based': 2,
#  'pairs': 1,
#  'Chi': 1,
#  'refers': 1,
#  'approaches': 1,
#  'asymptotically': 1,
#  'meaning': 1,
#  'sampling': 1,
#  'approximates': 1,
#  'closely': 1,
#  'sample': 13,
#  'sizes': 2,
#  'increase': 1,
#  '19th': 2,
#  'century': 2,
#  'analytical': 1,
#  'methods': 1,
#  'mainly': 1,
#  'applied': 1,
#  'biological': 2,
#  'data': 2,
#  'analysis': 2,
#  'customary': 1,
#  'researchers': 1,
#  'assume': 2,
#  'followed': 1,
#  'normal': 4,
#  'Sir': 1,
#  'George': 1,
#  'Airy': 1,
#  'Professor': 1,
#  'Merriman': 1,
#  'works': 1,
#  'criticized': 1,
#  'Karl': 1,
#  'paper.[1': 1,
#  'end': 1,
#  'noticed': 1,
#  'existence': 1,
#  'skewness': 1,
#  'order': 1,
#  'model': 3,
#  'regardless': 1,
#  'skewed': 2,
#  'series': 1,
#  'articles': 1,
#  'published': 2,
#  '1916,[2][3][4][5': 1,
#  'devised': 1,
#  'family': 1,
#  'continuous': 2,
#  'probability': 3,
#  'distributions': 2,
#  'includes': 1,
#  'proposed': 2,
#  'method': 2,
#  'consisting': 1,
#  'observation': 2,
#  'performing': 1,
#  'goodness': 3,
#  'fit': 3,
#  'fits': 1,
#  'paper[1': 1,
#  'considered': 2,
#  'foundations': 1,
#  'modern': 2,
#  'statistics.[6': 1,
#  'paper': 1,
#  'investigated': 1,
#  'Suppose': 4,
#  'n': 6,
#  'k': 3,
#  'respective': 1,
#  'numbers': 7,
#  'xi': 2,
#  '1,2,': 1,
#  '…': 1,
#  ',k': 1,
#  'gives': 1,
#  'pi': 1,
#  'falls': 1,
#  'ith': 1,
#  'class': 1,
#  'mi': 3,
#  'npi': 1,
#  'circumstance': 1,
#  'correct': 2,
#  '→': 1,
#  '∞': 1,
#  'limiting': 1,
#  'quantity': 1,
#  'given': 2,
#  'dealt': 1,
#  'case': 4,
#  'large': 3,
#  'known': 1,
#  'cells': 2,
#  'taken': 3,
#  'reached': 1,
#  'result': 2,
#  'X2': 1,
#  '−': 3,
#  'degrees': 4,
#  'freedom': 4,
#  'depended': 1,
#  'parameters': 1,
#  'estimated': 2,
#  'suggested': 2,
#  'notation': 1,
#  'm′i': 1,
#  'usually': 2,
#  'positive': 1,
#  'small': 2,
#  'omitted': 1,
#  'conclusion': 2,
#  'argued': 1,
#  'regarded': 1,
#  'X′2': 1,
#  'error': 4,
#  'approximation': 2,
#  'affect': 1,
#  'practical': 2,
#  'decisions': 1,
#  'caused': 1,
#  'controversy': 1,
#  'settled': 1,
#  'years': 1,
#  'Fisher': 2,
#  'papers.[7][8': 1,
#  'exactly': 1,
#  'variance': 7,
#  'value': 10,
#  'uncommon': 1,
#  'practice': 1,
#  'unknown': 1,
#  'approximately': 2,
#  'exact': 3,
#  'place': 2,
#  'x': 2,
#  'Binomial': 1,
#  'interpret': 1,
#  'requires': 1,
#  'discrete': 1,
#  'binomial': 1,
#  'approximated': 1,
#  'assumption': 2,
#  'introduces': 1,
#  'reduce': 1,
#  'Frank': 1,
#  'Yates': 1,
#  'correction': 1,
#  'continuity': 1,
#  'adjusts': 1,
#  'formula': 1,
#  'subtracting': 1,
#  '0.5': 1,
#  'absolute': 1,
#  '×': 1,
#  'table.[9': 1,
#  'reduces': 1,
#  'obtained': 1,
#  'increases': 1,
#  'p': 1,
#  'size': 2,
#  'having': 1,
#  'allows': 1,
#  'pre': 1,
#  'determined': 2,
#  'example': 2,
#  'manufacturing': 1,
#  'process': 2,
#  'stable': 1,
#  'condition': 1,
#  'long': 1,
#  'period': 1,
#  'allowing': 1,
#  'essentially': 1,
#  'variant': 1,
#  'tested': 3,
#  'giving': 2,
#  'rise': 1,
#  'product': 1,
#  'items': 1,
#  'variation': 1,
#  'T': 3,
#  'instance': 1,
#  'set': 1,
#  'sum': 3,
#  'squares': 1,
#  'mean': 1,
#  'divided': 1,
#  'nominal': 1,
#  'i.e.': 1,
#  'holding': 1,
#  'acceptance': 1,
#  'region': 1,
#  'significance': 1,
#  'level': 1,
#  '9.59': 1,
#  '34.17': 1,
#  'city': 2,
#  '1,000,000': 3,
#  'residents': 5,
#  'neighborhoods': 5,
#  'B': 1,
#  'C': 1,
#  'D.': 1,
#  'occupation': 1,
#  'recorded': 1,
#  'white': 4,
#  'collar': 8,
#  'blue': 2,
#  'person': 2,
#  'neighborhood': 6,
#  'residence': 1,
#  'occupational': 1,
#  'classification': 1,
#  ' ': 9,
#  'tabulated': 1,
#  'Let': 1,
#  'living': 1,
#  'estimate': 2,
#  'proportion': 2,
#  'live': 1,
#  'A.': 1,
#  'Similarly': 1,
#  '349/650': 1,
#  'workers': 3,
#  'expect': 1,
#  'number': 2,
#  'cell': 1,
#  'quantities': 1,
#  '\n\n\n\n': 1,
#  '≈': 1,
#  '24.6': 2,
#  '\n\n\n': 1,
#  '\\displaystyle': 1,
#  '\\approx': 1,
#  '\n\n': 1,
#  'improbably': 1,
#  'according': 1,
#  'rejects': 1,
#  'related': 1,
#  'issue': 1,
#  'homogeneity': 2,
#  'instead': 1,
#  'resident': 2,
#  'equal': 1,
#  'chance': 2,
#  'inclusion': 1,
#  'decide': 1,
#  'advance': 1,
#  'include': 1,
#  'chosen': 2,
#  'different': 3,
#  'probabilities': 1,
#  'proportional': 1,
#  'populations': 1,
#  'question': 1,
#  'proportions': 1,
#  'way': 1,
#  'cryptanalysis': 1,
#  'compare': 2,
#  'plaintext': 1,
#  'possibly': 1,
#  'decrypted': 1,
#  'ciphertext': 1,
#  'lowest': 1,
#  'means': 1,
#  'decryption': 1,
#  'successful': 1,
#  'high': 1,
#  'probability.[10][11': 1,
#  'generalized': 1,
#  'solving': 1,
#  'cryptographic': 1,
#  'problems.[12': 1,
#  'bioinformatics': 1,
#  'certain': 2,
#  'properties': 1,
#  'genes': 4,
#  'e.g.': 2,
#  'genomic': 1,
#  'content': 1,
#  'mutation': 1,
#  'rate': 1,
#  'interaction': 1,
#  'network': 1,
#  'clustering': 1,
#  'etc': 1,
#  'belonging': 1,
#  'disease': 1,
#  'essential': 1,
#  'chromosome': 1,
#  'etc.).[13][14': 1}

# %%
max_frequency = max(word_frequencies.values())
max_frequency
# Out:
# 32

# %%
max_key = max(word_frequencies,key = word_frequencies.get)
max_key
# Out:
# 'test'

# %%
#finding the weighted frequency to be use by the model
for word in word_frequencies.keys():
    word_frequencies[word] = word_frequencies[word]/max_frequency

# %%
word_frequencies
# Out:
# {'chi': 0.59375,
#  'squared': 0.625,
#  'test': 1.0,
#  'written': 0.03125,
#  'χ2': 0.28125,
#  'statistical': 0.125,
#  'hypothesis': 0.375,
#  'valid': 0.0625,
#  'perform': 0.03125,
#  'statistic': 0.28125,
#  'distributed': 0.15625,
#  'null': 0.3125,
#  'specifically': 0.03125,
#  'Pearson': 0.46875,
#  'variants': 0.03125,
#  'thereof': 0.03125,
#  'determine': 0.0625,
#  'statistically': 0.03125,
#  'significant': 0.0625,
#  'difference': 0.09375,
#  'expected': 0.21875,
#  'frequencies': 0.125,
#  'observed': 0.15625,
#  'categories': 0.0625,
#  'contingency': 0.0625,
#  'table': 0.09375,
#  'standard': 0.03125,
#  'applications': 0.0625,
#  'observations': 0.28125,
#  'classified': 0.0625,
#  'mutually': 0.0625,
#  'exclusive': 0.0625,
#  'classes': 0.09375,
#  'differences': 0.03125,
#  'population': 0.1875,
#  'true': 0.15625,
#  'computed': 0.03125,
#  'follows': 0.09375,
#  'frequency': 0.03125,
#  'distribution': 0.78125,
#  'purpose': 0.03125,
#  'evaluate': 0.03125,
#  'likely': 0.03125,
#  'assuming': 0.0625,
#  'Test': 0.03125,
#  'statistics': 0.03125,
#  'follow': 0.03125,
#  'occur': 0.03125,
#  'independent': 0.0625,
#  'normally': 0.09375,
#  'assumptions': 0.03125,
#  'justified': 0.03125,
#  'central': 0.03125,
#  'limit': 0.0625,
#  'theorem': 0.03125,
#  'tests': 0.15625,
#  'testing': 0.0625,
#  'independence': 0.15625,
#  'pair': 0.03125,
#  'random': 0.09375,
#  'variables': 0.03125,
#  'based': 0.0625,
#  'pairs': 0.03125,
#  'Chi': 0.03125,
#  'refers': 0.03125,
#  'approaches': 0.03125,
#  'asymptotically': 0.03125,
#  'meaning': 0.03125,
#  'sampling': 0.03125,
#  'approximates': 0.03125,
#  'closely': 0.03125,
#  'sample': 0.40625,
#  'sizes': 0.0625,
#  'increase': 0.03125,
#  '19th': 0.0625,
#  'century': 0.0625,
#  'analytical': 0.03125,
#  'methods': 0.03125,
#  'mainly': 0.03125,
#  'applied': 0.03125,
#  'biological': 0.0625,
#  'data': 0.0625,
#  'analysis': 0.0625,
#  'customary': 0.03125,
#  'researchers': 0.03125,
#  'assume': 0.0625,
#  'followed': 0.03125,
#  'normal': 0.125,
#  'Sir': 0.03125,
#  'George': 0.03125,
#  'Airy': 0.03125,
#  'Professor': 0.03125,
#  'Merriman': 0.03125,
#  'works': 0.03125,
#  'criticized': 0.03125,
#  'Karl': 0.03125,
#  'paper.[1': 0.03125,
#  'end': 0.03125,
#  'noticed': 0.03125,
#  'existence': 0.03125,
#  'skewness': 0.03125,
#  'order': 0.03125,
#  'model': 0.09375,
#  'regardless': 0.03125,
#  'skewed': 0.0625,
#  'series': 0.03125,
#  'articles': 0.03125,
#  'published': 0.0625,
#  '1916,[2][3][4][5': 0.03125,
#  'devised': 0.03125,
#  'family': 0.03125,
#  'continuous': 0.0625,
#  'probability': 0.09375,
#  'distributions': 0.0625,
#  'includes': 0.03125,
#  'proposed': 0.0625,
#  'method': 0.0625,
#  'consisting': 0.03125,
#  'observation': 0.0625,
#  'performing': 0.03125,
#  'goodness': 0.09375,
#  'fit': 0.09375,
#  'fits': 0.03125,
#  'paper[1': 0.03125,
#  'considered': 0.0625,
#  'foundations': 0.03125,
#  'modern': 0.0625,
#  'statistics.[6': 0.03125,
#  'paper': 0.03125,
#  'investigated': 0.03125,
#  'Suppose': 0.125,
#  'n': 0.1875,
#  'k': 0.09375,
#  'respective': 0.03125,
#  'numbers': 0.21875,
#  'xi': 0.0625,
#  '1,2,': 0.03125,
#  '…': 0.03125,
#  ',k': 0.03125,
#  'gives': 0.03125,
#  'pi': 0.03125,
#  'falls': 0.03125,
#  'ith': 0.03125,
#  'class': 0.03125,
#  'mi': 0.09375,
#  'npi': 0.03125,
#  'circumstance': 0.03125,
#  'correct': 0.0625,
#  '→': 0.03125,
#  '∞': 0.03125,
#  'limiting': 0.03125,
#  'quantity': 0.03125,
#  'given': 0.0625,
#  'dealt': 0.03125,
#  'case': 0.125,
#  'large': 0.09375,
#  'known': 0.03125,
#  'cells': 0.0625,
#  'taken': 0.09375,
#  'reached': 0.03125,
#  'result': 0.0625,
#  'X2': 0.03125,
#  '−': 0.09375,
#  'degrees': 0.125,
#  'freedom': 0.125,
#  'depended': 0.03125,
#  'parameters': 0.03125,
#  'estimated': 0.0625,
#  'suggested': 0.0625,
#  'notation': 0.03125,
#  'm′i': 0.03125,
#  'usually': 0.0625,
#  'positive': 0.03125,
#  'small': 0.0625,
#  'omitted': 0.03125,
#  'conclusion': 0.0625,
#  'argued': 0.03125,
#  'regarded': 0.03125,
#  'X′2': 0.03125,
#  'error': 0.125,
#  'approximation': 0.0625,
#  'affect': 0.03125,
#  'practical': 0.0625,
#  'decisions': 0.03125,
#  'caused': 0.03125,
#  'controversy': 0.03125,
#  'settled': 0.03125,
#  'years': 0.03125,
#  'Fisher': 0.0625,
#  'papers.[7][8': 0.03125,
#  'exactly': 0.03125,
#  'variance': 0.21875,
#  'value': 0.3125,
#  'uncommon': 0.03125,
#  'practice': 0.03125,
#  'unknown': 0.03125,
#  'approximately': 0.0625,
#  'exact': 0.09375,
#  'place': 0.0625,
#  'x': 0.0625,
#  'Binomial': 0.03125,
#  'interpret': 0.03125,
#  'requires': 0.03125,
#  'discrete': 0.03125,
#  'binomial': 0.03125,
#  'approximated': 0.03125,
#  'assumption': 0.0625,
#  'introduces': 0.03125,
#  'reduce': 0.03125,
#  'Frank': 0.03125,
#  'Yates': 0.03125,
#  'correction': 0.03125,
#  'continuity': 0.03125,
#  'adjusts': 0.03125,
#  'formula': 0.03125,
#  'subtracting': 0.03125,
#  '0.5': 0.03125,
#  'absolute': 0.03125,
#  '×': 0.03125,
#  'table.[9': 0.03125,
#  'reduces': 0.03125,
#  'obtained': 0.03125,
#  'increases': 0.03125,
#  'p': 0.03125,
#  'size': 0.0625,
#  'having': 0.03125,
#  'allows': 0.03125,
#  'pre': 0.03125,
#  'determined': 0.0625,
#  'example': 0.0625,
#  'manufacturing': 0.03125,
#  'process': 0.0625,
#  'stable': 0.03125,
#  'condition': 0.03125,
#  'long': 0.03125,
#  'period': 0.03125,
#  'allowing': 0.03125,
#  'essentially': 0.03125,
#  'variant': 0.03125,
#  'tested': 0.09375,
#  'giving': 0.0625,
#  'rise': 0.03125,
#  'product': 0.03125,
#  'items': 0.03125,
#  'variation': 0.03125,
#  'T': 0.09375,
#  'instance': 0.03125,
#  'set': 0.03125,
#  'sum': 0.09375,
#  'squares': 0.03125,
#  'mean': 0.03125,
#  'divided': 0.03125,
#  'nominal': 0.03125,
#  'i.e.': 0.03125,
#  'holding': 0.03125,
#  'acceptance': 0.03125,
#  'region': 0.03125,
#  'significance': 0.03125,
#  'level': 0.03125,
#  '9.59': 0.03125,
#  '34.17': 0.03125,
#  'city': 0.0625,
#  '1,000,000': 0.09375,
#  'residents': 0.15625,
#  'neighborhoods': 0.15625,
#  'B': 0.03125,
#  'C': 0.03125,
#  'D.': 0.03125,
#  'occupation': 0.03125,
#  'recorded': 0.03125,
#  'white': 0.125,
#  'collar': 0.25,
#  'blue': 0.0625,
#  'person': 0.0625,
#  'neighborhood': 0.1875,
#  'residence': 0.03125,
#  'occupational': 0.03125,
#  'classification': 0.03125,
#  ' ': 0.28125,
#  'tabulated': 0.03125,
#  'Let': 0.03125,
#  'living': 0.03125,
#  'estimate': 0.0625,
#  'proportion': 0.0625,
#  'live': 0.03125,
#  'A.': 0.03125,
#  'Similarly': 0.03125,
#  '349/650': 0.03125,
#  'workers': 0.09375,
#  'expect': 0.03125,
#  'number': 0.0625,
#  'cell': 0.03125,
#  'quantities': 0.03125,
#  '\n\n\n\n': 0.03125,
#  '≈': 0.03125,
#  '24.6': 0.0625,
#  '\n\n\n': 0.03125,
#  '\\displaystyle': 0.03125,
#  '\\approx': 0.03125,
#  '\n\n': 0.03125,
#  'improbably': 0.03125,
#  'according': 0.03125,
#  'rejects': 0.03125,
#  'related': 0.03125,
#  'issue': 0.03125,
#  'homogeneity': 0.0625,
#  'instead': 0.03125,
#  'resident': 0.0625,
#  'equal': 0.03125,
#  'chance': 0.0625,
#  'inclusion': 0.03125,
#  'decide': 0.03125,
#  'advance': 0.03125,
#  'include': 0.03125,
#  'chosen': 0.0625,
#  'different': 0.09375,
#  'probabilities': 0.03125,
#  'proportional': 0.03125,
#  'populations': 0.03125,
#  'question': 0.03125,
#  'proportions': 0.03125,
#  'way': 0.03125,
#  'cryptanalysis': 0.03125,
#  'compare': 0.0625,
#  'plaintext': 0.03125,
#  'possibly': 0.03125,
#  'decrypted': 0.03125,
#  'ciphertext': 0.03125,
#  'lowest': 0.03125,
#  'means': 0.03125,
#  'decryption': 0.03125,
#  'successful': 0.03125,
#  'high': 0.03125,
#  'probability.[10][11': 0.03125,
#  'generalized': 0.03125,
#  'solving': 0.03125,
#  'cryptographic': 0.03125,
#  'problems.[12': 0.03125,
#  'bioinformatics': 0.03125,
#  'certain': 0.0625,
#  'properties': 0.03125,
#  'genes': 0.125,
#  'e.g.': 0.0625,
#  'genomic': 0.03125,
#  'content': 0.03125,
#  'mutation': 0.03125,
#  'rate': 0.03125,
#  'interaction': 0.03125,
#  'network': 0.03125,
#  'clustering': 0.03125,
#  'etc': 0.03125,
#  'belonging': 0.03125,
#  'disease': 0.03125,
#  'essential': 0.03125,
#  'chromosome': 0.03125,
#  'etc.).[13][14': 0.03125}

# %%
import pandas as pd
df = pd.DataFrame(list(word_frequencies.items()), columns = ['Word','Frequency'])
df
# Out:
#               Word  Frequency
# 0              chi    0.59375
# 1          squared    0.62500
# 2             test    1.00000
# 3          written    0.03125
# 4               χ2    0.28125
# ..             ...        ...
# 351      belonging    0.03125
# 352        disease    0.03125
# 353      essential    0.03125
# 354     chromosome    0.03125
# 355  etc.).[13][14    0.03125
#
# [356 rows x 2 columns]

# %%
#tokenization of sentence
sentence_token = [sentence for sentence in doc.sents]
print(sentence_token)
# Out:
# [A chi-squared test, also written as χ2 test, is a statistical hypothesis test that is valid to perform when the test statistic is chi-squared distributed under the null hypothesis, specifically Pearson's chi-squared test and variants thereof., Pearson's chi-squared test is used to determine whether there is a statistically significant difference between the expected frequencies and the observed frequencies in one or more categories of a contingency table.
# , In the standard applications of this test, the observations are classified into mutually exclusive classes., If the null hypothesis that there are no differences between the classes in the population is true, the test statistic computed from the observations follows a χ2 frequency distribution., The purpose of the test is to evaluate how likely the observed frequencies would be assuming the null hypothesis is true.
# , Test statistics that follow a χ2 distribution occur when the observations are independent and normally distributed, which assumptions are often justified under the central limit theorem., There are also χ2 tests for testing the null hypothesis of independence of a pair of random variables based on observations of the pairs.
# , Chi-squared tests often refers to tests for which the distribution of the test statistic approaches the χ2 distribution asymptotically, meaning that the sampling distribution (if the null hypothesis is true) of the test statistic approximates a chi-squared distribution more and more closely as sample sizes increase.
# , In the 19th century, statistical analytical methods were mainly applied in biological data analysis and it was customary for researchers to assume that observations followed a normal distribution, such as Sir George Airy and Professor Merriman, whose works were criticized by Karl Pearson in his 1900 paper.[1]
# , At the end of 19th century, Pearson noticed the existence of significant skewness within some biological observations., In order to model the observations regardless of being normal or skewed, Pearson, in a series of articles published from 1893 to 1916,[2][3][4][5] devised the Pearson distribution, a family of continuous probability distributions, which includes the normal distribution and many skewed distributions, and proposed a method of statistical analysis consisting of using the Pearson distribution to model the observation and performing a test of goodness of fit to determine how well the model really fits to the observations.
# , In 1900, Pearson published a paper[1] on the χ2 test which is considered to be one of the foundations of modern statistics.[6], In this paper, Pearson investigated a test of goodness of fit.
# , Suppose that n observations in a random sample from a population are classified into k mutually exclusive classes with respective observed numbers xi (for i = 1,2,…,k), and a null hypothesis gives the probability pi that an observation falls into the ith class., So we have the expected numbers mi =, npi for all i, where
# Pearson proposed that, under the circumstance of the null hypothesis being correct, as n → ∞ the limiting distribution of the quantity given below is the χ2 distribution.
# , Pearson dealt first with the case in which the expected numbers mi are large enough known numbers in all cells assuming every xi may be taken as normally distributed, and reached the result that, in the limit as n becomes large, X2 follows the χ2 distribution with k − 1 degrees of freedom.
# , However, Pearson next considered the case in which the expected numbers depended on the parameters that had to be estimated from the sample, and suggested that, with the notation of mi being the true expected numbers and m′i being the estimated expected numbers, the difference
# will usually be positive and small enough to be omitted., In a conclusion, Pearson argued that if we regarded X′2 as also distributed as χ2 distribution with k − 1 degrees of freedom, the error in this approximation would not affect practical decisions., This conclusion caused some controversy in practical applications and was not settled for 20 years until Fisher's 1922 and 1924 papers.[7][8]
# , One test statistic that follows a chi-squared distribution exactly is the test that the variance of a normally distributed population has a given value based on a sample variance., Such tests are uncommon in practice because the true variance of the population is usually unknown., However, there are several statistical tests where the chi-squared distribution is approximately valid:
# , For an exact test used in place of the 2 x 2 chi-squared test for independence, see Fisher's exact test.
# , For an exact test used in place of the 2 x 1 chi-squared test for goodness of fit, see Binomial test.
# , Using the chi-squared distribution to interpret Pearson's chi-squared statistic requires one to assume that the discrete probability of observed binomial frequencies in the table can be approximated by the continuous chi-squared distribution., This assumption is not quite correct and introduces some error.
# , To reduce the error in approximation, Frank Yates suggested a correction for continuity that adjusts the formula for Pearson's chi-squared test by subtracting 0.5 from the absolute difference between each observed value and its expected value in a 2 × 2 contingency table.[9], This reduces the chi-squared value obtained and thus increases its p-value.
# , If a sample of size n is taken from a population having a normal distribution, then there is a result (see distribution of the sample variance) which allows a test to be made of whether the variance of the population has a pre-determined value., For example, a manufacturing process might have been in stable condition for a long period, allowing a value for the variance to be determined essentially without error., Suppose that a variant of the process is being tested, giving rise to a small sample of n product items whose variation is to be tested., The test statistic T in this instance could be set to be the sum of squares about the sample mean, divided by the nominal value for the variance (i.e. the value to be tested as holding)., Then T has a chi-squared distribution with n − 1 degrees of freedom., For example, if the sample size is 21, the acceptance region for T with a significance level of 5% is between 9.59 and 34.17.
# , Suppose there is a city of 1,000,000 residents with four neighborhoods:, A, B, C, and D. A random sample of 650 residents of the city is taken and their occupation is recorded as "white collar", "blue collar", or "no collar"., The null hypothesis is that each person's neighborhood of residence is independent of the person's occupational classification.  , The data are tabulated as:
# , Let us take the sample living in neighborhood A, 150, to estimate what proportion of the whole 1,000,000 live in neighborhood A.  , Similarly we take 349/650 to estimate what proportion of the 1,000,000 are white-collar workers.  , By the assumption of independence under the hypothesis we should "expect" the number of white-collar workers in neighborhood A to be
# , Then in that "cell" of the table, we have
# The sum of these quantities over all of the cells is the test statistic;, in this case,
#
#
#
# ≈
# 24.6
#
#
# {\displaystyle \approx 24.6}
#
# .  , Under the null hypothesis, this sum has approximately a chi-squared distribution whose number of degrees of freedom are
# If the test statistic is improbably large according to that chi-squared distribution, then one rejects the null hypothesis of independence.
# , A related issue is a test of homogeneity.  , Suppose that instead of giving every resident of each of the four neighborhoods an equal chance of inclusion in the sample, we decide in advance how many residents of each neighborhood to include.  , Then each resident has the same chance of being chosen as do all residents of the same neighborhood, but residents of different neighborhoods would have different probabilities of being chosen if the four sample sizes are not proportional to the populations of the four neighborhoods.  , In such a case, we would be testing "homogeneity" rather than "independence".  , The question is whether the proportions of blue-collar, white-collar, and no-collar workers in the four neighborhoods are the same.  , However, the test is done in the same way.
# , In cryptanalysis, the chi-squared test is used to compare the distribution of plaintext and (possibly) decrypted ciphertext., The lowest value of the test means that the decryption was successful with high probability.[10][11], This method can be generalized for solving modern cryptographic problems.[12]
# , In bioinformatics, chi-squared test is used to compare the distribution of certain properties of genes (e.g., genomic content, mutation rate, interaction network clustering, etc.), belonging to different categories (e.g., disease genes, essential genes, genes on a certain chromosome etc.).[13][14]
# ]

# %%
sentence_score = {}

for sentence in sentence_token:
    for word in sentence:
        if word.text.lower() in word_frequencies.keys():
            if sentence not in sentence_score.keys():
                sentence_score[sentence] = word_frequencies[word.text.lower()]
            else:
                sentence_score[sentence] += word_frequencies[word.text.lower()]

# %%
sentence_score
# Out:
# {A chi-squared test, also written as χ2 test, is a statistical hypothesis test that is valid to perform when the test statistic is chi-squared distributed under the null hypothesis, specifically Pearson's chi-squared test and variants thereof.: 10.78125,
#  Pearson's chi-squared test is used to determine whether there is a statistically significant difference between the expected frequencies and the observed frequencies in one or more categories of a contingency table. : 3.3125,
#  In the standard applications of this test, the observations are classified into mutually exclusive classes.: 1.65625,
#  If the null hypothesis that there are no differences between the classes in the population is true, the test statistic computed from the observations follows a χ2 frequency distribution.: 3.9375,
#  The purpose of the test is to evaluate how likely the observed frequencies would be assuming the null hypothesis is true.: 2.28125,
#  Test statistics that follow a χ2 distribution occur when the observations are independent and normally distributed, which assumptions are often justified under the central limit theorem.: 2.9375,
#  There are also χ2 tests for testing the null hypothesis of independence of a pair of random variables based on observations of the pairs.: 1.875,
#  Chi-squared tests often refers to tests for which the distribution of the test statistic approaches the χ2 distribution asymptotically, meaning that the sampling distribution (if the null hypothesis is true) of the test statistic approximates a chi-squared distribution more and more closely as sample sizes increase.: 10.28125,
#  In the 19th century, statistical analytical methods were mainly applied in biological data analysis and it was customary for researchers to assume that observations followed a normal distribution, such as Sir George Airy and Professor Merriman, whose works were criticized by Karl Pearson in his 1900 paper.[1]: 2.0,
#  At the end of 19th century, Pearson noticed the existence of significant skewness within some biological observations.: 0.65625,
#  In order to model the observations regardless of being normal or skewed, Pearson, in a series of articles published from 1893 to 1916,[2][3][4][5] devised the Pearson distribution, a family of continuous probability distributions, which includes the normal distribution and many skewed distributions, and proposed a method of statistical analysis consisting of using the Pearson distribution to model the observation and performing a test of goodness of fit to determine how well the model really fits to the observations.: 5.875,
#  In 1900, Pearson published a paper[1] on the χ2 test which is considered to be one of the foundations of modern statistics.[6]: 1.5625,
#  In this paper, Pearson investigated a test of goodness of fit.: 1.25,
#  Suppose that n observations in a random sample from a population are classified into k mutually exclusive classes with respective observed numbers xi (for i = 1,2,…,k), and a null hypothesis gives the probability pi that an observation falls into the ith class.: 3.09375,
#  So we have the expected numbers mi =: 0.53125,
#  npi for all i, where
#  Pearson proposed that, under the circumstance of the null hypothesis being correct, as n → ∞ the limiting distribution of the quantity given below is the χ2 distribution.: 3.09375,
#  Pearson dealt first with the case in which the expected numbers mi are large enough known numbers in all cells assuming every xi may be taken as normally distributed, and reached the result that, in the limit as n becomes large, X2 follows the χ2 distribution with k − 1 degrees of freedom.: 3.59375,
#  However, Pearson next considered the case in which the expected numbers depended on the parameters that had to be estimated from the sample, and suggested that, with the notation of mi being the true expected numbers and m′i being the estimated expected numbers, the difference
#  will usually be positive and small enough to be omitted.: 2.75,
#  In a conclusion, Pearson argued that if we regarded X′2 as also distributed as χ2 distribution with k − 1 degrees of freedom, the error in this approximation would not affect practical decisions.: 2.09375,
#  This conclusion caused some controversy in practical applications and was not settled for 20 years until Fisher's 1922 and 1924 papers.[7][8]: 0.34375,
#  One test statistic that follows a chi-squared distribution exactly is the test that the variance of a normally distributed population has a given value based on a sample variance.: 6.125,
#  Such tests are uncommon in practice because the true variance of the population is usually unknown.: 0.875,
#  However, there are several statistical tests where the chi-squared distribution is approximately valid:: 2.40625,
#  For an exact test used in place of the 2 x 2 chi-squared test for independence, see Fisher's exact test.: 4.6875,
#  For an exact test used in place of the 2 x 1 chi-squared test for goodness of fit, see Binomial test.: 4.65625,
#  Using the chi-squared distribution to interpret Pearson's chi-squared statistic requires one to assume that the discrete probability of observed binomial frequencies in the table can be approximated by the continuous chi-squared distribution.: 6.25,
#  This assumption is not quite correct and introduces some error.: 0.28125,
#  To reduce the error in approximation, Frank Yates suggested a correction for continuity that adjusts the formula for Pearson's chi-squared test by subtracting 0.5 from the absolute difference between each observed value and its expected value in a 2 × 2 contingency table.[9]: 3.9375,
#  This reduces the chi-squared value obtained and thus increases its p-value.: 1.96875,
#  If a sample of size n is taken from a population having a normal distribution, then there is a result (see distribution of the sample variance) which allows a test to be made of whether the variance of the population has a pre-determined value.: 5.1875,
#  For example, a manufacturing process might have been in stable condition for a long period, allowing a value for the variance to be determined essentially without error.: 1.0625,
#  Suppose that a variant of the process is being tested, giving rise to a small sample of n product items whose variation is to be tested.: 1.125,
#  The test statistic T in this instance could be set to be the sum of squares about the sample mean, divided by the nominal value for the variance (i.e. the value to be tested as holding).: 2.96875,
#  Then T has a chi-squared distribution with n − 1 degrees of freedom.: 2.53125,
#  For example, if the sample size is 21, the acceptance region for T with a significance level of 5% is between 9.59 and 34.17.: 0.71875,
#  Suppose there is a city of 1,000,000 residents with four neighborhoods:: 0.46875,
#  A, B, C, and D. A random sample of 650 residents of the city is taken and their occupation is recorded as "white collar", "blue collar", or "no collar".: 1.8125,
#  The null hypothesis is that each person's neighborhood of residence is independent of the person's occupational classification.  : 1.4375,
#  The data are tabulated as:: 0.09375,
#  Let us take the sample living in neighborhood A, 150, to estimate what proportion of the whole 1,000,000 live in neighborhood A.  : 1.34375,
#  Similarly we take 349/650 to estimate what proportion of the 1,000,000 are white-collar workers.  : 1.0,
#  By the assumption of independence under the hypothesis we should "expect" the number of white-collar workers in neighborhood A to be: 1.34375,
#  Then in that "cell" of the table, we have
#  The sum of these quantities over all of the cells is the test statistic;: 1.59375,
#  in this case,
#
#
#
#  ≈
#  24.6
#
#
#  {\displaystyle \approx 24.6}
#
#  .  : 0.71875,
#  Under the null hypothesis, this sum has approximately a chi-squared distribution whose number of degrees of freedom are
#  If the test statistic is improbably large according to that chi-squared distribution, then one rejects the null hypothesis of independence.: 7.46875,
#  A related issue is a test of homogeneity.  : 1.40625,
#  Suppose that instead of giving every resident of each of the four neighborhoods an equal chance of inclusion in the sample, we decide in advance how many residents of each neighborhood to include.  : 1.5625,
#  Then each resident has the same chance of being chosen as do all residents of the same neighborhood, but residents of different neighborhoods would have different probabilities of being chosen if the four sample sizes are not proportional to the populations of the four neighborhoods.  : 2.09375,
#  In such a case, we would be testing "homogeneity" rather than "independence".  : 0.6875,
#  The question is whether the proportions of blue-collar, white-collar, and no-collar workers in the four neighborhoods are the same.  : 1.53125,
#  However, the test is done in the same way.: 1.03125,
#  In cryptanalysis, the chi-squared test is used to compare the distribution of plaintext and (possibly) decrypted ciphertext.: 3.21875,
#  The lowest value of the test means that the decryption was successful with high probability.[10][11]: 1.5,
#  This method can be generalized for solving modern cryptographic problems.[12]: 0.25,
#  In bioinformatics, chi-squared test is used to compare the distribution of certain properties of genes (e.g., genomic content, mutation rate, interaction network clustering, etc.): 3.625,
#  belonging to different categories (e.g., disease genes, essential genes, genes on a certain chromosome etc.).[13][14]: 0.8125}

# %%
#to select n-largest weighted sentence from the text data
from heapq import nlargest

# %%
#extracting out only 20% of the text data as summary
summary_length = int(len(sentence_token)*0.2)

# %%
summary_length
# Out:
# 11

# %% [markdown]
# Thus, we will extract out only the top 16 sentence based on the weighted frequency alloted to frame its summary.

# %%
summary = nlargest(summary_length,sentence_score,key = sentence_score.get)

# %%
summary
# Out:
# [A chi-squared test, also written as χ2 test, is a statistical hypothesis test that is valid to perform when the test statistic is chi-squared distributed under the null hypothesis, specifically Pearson's chi-squared test and variants thereof.,
#  Chi-squared tests often refers to tests for which the distribution of the test statistic approaches the χ2 distribution asymptotically, meaning that the sampling distribution (if the null hypothesis is true) of the test statistic approximates a chi-squared distribution more and more closely as sample sizes increase.,
#  Under the null hypothesis, this sum has approximately a chi-squared distribution whose number of degrees of freedom are
#  If the test statistic is improbably large according to that chi-squared distribution, then one rejects the null hypothesis of independence.,
#  Using the chi-squared distribution to interpret Pearson's chi-squared statistic requires one to assume that the discrete probability of observed binomial frequencies in the table can be approximated by the continuous chi-squared distribution.,
#  One test statistic that follows a chi-squared distribution exactly is the test that the variance of a normally distributed population has a given value based on a sample variance.,
#  In order to model the observations regardless of being normal or skewed, Pearson, in a series of articles published from 1893 to 1916,[2][3][4][5] devised the Pearson distribution, a family of continuous probability distributions, which includes the normal distribution and many skewed distributions, and proposed a method of statistical analysis consisting of using the Pearson distribution to model the observation and performing a test of goodness of fit to determine how well the model really fits to the observations.,
#  If a sample of size n is taken from a population having a normal distribution, then there is a result (see distribution of the sample variance) which allows a test to be made of whether the variance of the population has a pre-determined value.,
#  For an exact test used in place of the 2 x 2 chi-squared test for independence, see Fisher's exact test.,
#  For an exact test used in place of the 2 x 1 chi-squared test for goodness of fit, see Binomial test.,
#  If the null hypothesis that there are no differences between the classes in the population is true, the test statistic computed from the observations follows a χ2 frequency distribution.,
#  To reduce the error in approximation, Frank Yates suggested a correction for continuity that adjusts the formula for Pearson's chi-squared test by subtracting 0.5 from the absolute difference between each observed value and its expected value in a 2 × 2 contingency table.[9]]

# %%
final_summary = [word.text for word in summary]

# %%
final_summary
# Out:
# ["A chi-squared test, also written as χ2 test, is a statistical hypothesis test that is valid to perform when the test statistic is chi-squared distributed under the null hypothesis, specifically Pearson's chi-squared test and variants thereof.",
#  'Chi-squared tests often refers to tests for which the distribution of the test statistic approaches the χ2 distribution asymptotically, meaning that the sampling distribution (if the null hypothesis is true) of the test statistic approximates a chi-squared distribution more and more closely as sample sizes increase.\n',
#  'Under the null hypothesis, this sum has approximately a chi-squared distribution whose number of degrees of freedom are\nIf the test statistic is improbably large according to that chi-squared distribution, then one rejects the null hypothesis of independence.\n',
#  "Using the chi-squared distribution to interpret Pearson's chi-squared statistic requires one to assume that the discrete probability of observed binomial frequencies in the table can be approximated by the continuous chi-squared distribution.",
#  'One test statistic that follows a chi-squared distribution exactly is the test that the variance of a normally distributed population has a given value based on a sample variance.',
#  'In order to model the observations regardless of being normal or skewed, Pearson, in a series of articles published from 1893 to 1916,[2][3][4][5] devised the Pearson distribution, a family of continuous probability distributions, which includes the normal distribution and many skewed distributions, and proposed a method of statistical analysis consisting of using the Pearson distribution to model the observation and performing a test of goodness of fit to determine how well the model really fits to the observations.\n',
#  'If a sample of size n is taken from a population having a normal distribution, then there is a result (see distribution of the sample variance) which allows a test to be made of whether the variance of the population has a pre-determined value.',
#  "For an exact test used in place of the 2 x 2 chi-squared test for independence, see Fisher's exact test.\n",
#  'For an exact test used in place of the 2 x 1 chi-squared test for goodness of fit, see Binomial test.\n',
#  'If the null hypothesis that there are no differences between the classes in the population is true, the test statistic computed from the observations follows a χ2 frequency distribution.',
#  "To reduce the error in approximation, Frank Yates suggested a correction for continuity that adjusts the formula for Pearson's chi-squared test by subtracting 0.5 from the absolute difference between each observed value and its expected value in a 2 × 2 contingency table.[9]"]

# %%
final_summary = " ".join(final_summary)

# %%
final_summary
# Out:
# "A chi-squared test, also written as χ2 test, is a statistical hypothesis test that is valid to perform when the test statistic is chi-squared distributed under the null hypothesis, specifically Pearson's chi-squared test and variants thereof. Chi-squared tests often refers to tests for which the distribution of the test statistic approaches the χ2 distribution asymptotically, meaning that the sampling distribution (if the null hypothesis is true) of the test statistic approximates a chi-squared distribution more and more closely as sample sizes increase.\n Under the null hypothesis, this sum has approximately a chi-squared distribution whose number of degrees of freedom are\nIf the test statistic is improbably large according to that chi-squared distribution, then one rejects the null hypothesis of independence.\n Using the chi-squared distribution to interpret Pearson's chi-squared statistic requires one to assume that the discrete probability of observed binomial frequencies in the table can be approximated by the continuous chi-squared distribution. One test statistic that follows a chi-squared distribution exactly is the test that the variance of a normally distributed population has a given value based on a sample variance. In order to model the observations regardless of being normal or skewed, Pearson, in a series of articles published from 1893 to 1916,[2][3][4][5] devised the Pearson distribution, a family of continuous probability distributions, which includes the normal distribution and many skewed distributions, and proposed a method of statistical analysis consisting of using the Pearson distribution to model the observation and performing a test of goodness of fit to determine how well the model really fits to the observations.\n If a sample of size n is taken from a population having a normal distribution, then there is a result (see distribution of the sample variance) which allows a test to be made of whether the variance of the population has a pre-determined value. For an exact test used in place of the 2 x 2 chi-squared test for independence, see Fisher's exact test.\n For an exact test used in place of the 2 x 1 chi-squared test for goodness of fit, see Binomial test.\n If the null hypothesis that there are no differences between the classes in the population is true, the test statistic computed from the observations follows a χ2 frequency distribution. To reduce the error in approximation, Frank Yates suggested a correction for continuity that adjusts the formula for Pearson's chi-squared test by subtracting 0.5 from the absolute difference between each observed value and its expected value in a 2 × 2 contingency table.[9]"

# %%
len(article_text)
# Out:
# 8863

# %%
len(final_summary)
# Out:
# 2686
